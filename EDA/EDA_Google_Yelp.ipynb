# %% [markdown]
# # **Introducción al Análisis Exploratorio de Datos (EDA) del Proyecto "China Garden"**
#
# En un entorno competitivo y dinámico como el mercado de restaurantes en Estados Unidos, el análisis de datos se ha convertido en una herramienta esencial para entender la posición de una marca, anticipar tendencias y tomar decisiones estratégicas fundamentadas. En este proyecto, nuestro objetivo es realizar un análisis exploratorio de datos (EDA) para una reconocida cadena de restaurantes chinos, **China Garden**, con el fin de apoyar su estrategia de expansión en la costa este del país.
#
# El EDA proporcionará una base sólida para identificar oportunidades de crecimiento y optimización operativa, analizando tanto datos de desempeño actual como información sobre la competencia. Este análisis también permitirá evaluar factores clave como la satisfacción del cliente, la presencia de mercado, y las ubicaciones óptimas para nuevos restaurantes.
#
# #### **Objetivos del Análisis Exploratorio de Datos**
#
# Para lograr los objetivos generales del proyecto, nuestro EDA se centrará en los siguientes puntos:
#
# 1. **Revisión de Tipos de Datos y Descripción de Datasets:**
#    - Examinar los tipos de datos por columna en cada dataset disponible para asegurar su adecuación al análisis posterior. Se incluirá una descripción detallada de cada dataset, abordando su propósito y relevancia en el contexto del proyecto.
#
# 2. **Justificación de la Eliminación de Columnas:**
#    - Analizar y explicar la eliminación de columnas que no aportan valor al análisis o que presentan datos inconsistentes. Esta etapa es fundamental para mejorar la eficiencia del procesamiento de datos y mantener la integridad del análisis.
#
# 3. **Identificación y Manejo de Valores Nulos:**
#    - Detectar los valores nulos en los datasets y proponer estrategias adecuadas de manejo, como la imputación de valores basados en la media, mediana o la eliminación de registros, dependiendo de la relevancia y el impacto de los datos faltantes.
#
# 4. **Detección y Tratamiento de Registros Duplicados:**
#    - Identificar registros duplicados que puedan sesgar el análisis. Proponer métodos para su tratamiento, como la eliminación de duplicados exactos o el análisis de duplicados parciales para decidir la mejor acción.
#
# 5. **Análisis Gráfico y Visualización de Datos:**
#    - Utilizar herramientas como **Matplotlib** y **Seaborn** para realizar análisis gráficos que permitan entender el comportamiento de los datos. Este enfoque incluirá, pero no se limitará a:
#      - Visualización de la distribución de restaurantes y hoteles en la costa este.
#      - Cálculo del porcentaje de mercado capturado por los restaurantes de comida china en comparación con otros tipos de restaurantes.
#      - Identificación de los 10 principales restaurantes de comida china en términos de cantidad, promedio de calificaciones y presencia de mercado.
#      - Análisis geográfico para entender la ubicación de los restaurantes de "China Garden" y su competencia directa.
#      - Análisis de las zonas con mayor concentración de hoteles para identificar las áreas de mayor interés turístico.
#      - Cualquier otro análisis pertinente que pueda ofrecer insights sobre el comportamiento del mercado y las oportunidades de expansión.
#
# 6. **Exportacion a Parquet**
#
# Este EDA servirá como el cimiento sobre el cual se basarán todos los análisis futuros, ayudando a identificar patrones y tendencias que orientarán las decisiones estratégicas de "China Garden". A través de un enfoque minucioso y detallado, buscaremos proporcionar un conocimiento profundo y detallado del mercado, permitiendo a la marca mejorar su posicionamiento y maximizar su potencial de crecimiento en la costa este de Estados Unidos.
#
# ### **Empecemos**

# %% [markdown]
# ## **1. Carga de datos Google maps**

# %% [markdown]
# **Descripción de los Datos de Google Maps**
#
# Para este proyecto, se han recopilado datos provenientes de Google Maps, una de las plataformas más utilizadas por los consumidores para compartir opiniones sobre sus experiencias en restaurantes. Estos datos se encuentran organizados en dos carpetas principales, cada una con una estructura específica que facilita el análisis detallado de la información.
#
# **1. Carpeta: Metadata Sitios**
#
# La carpeta Metadata Sitios contiene información relevante sobre los establecimientos de interés, en este caso, los restaurantes de comida china en la costa este de Estados Unidos. Esta carpeta incluye un total de 11 archivos JSON que deberán ser unificados en un solo archivo consolidado para facilitar su análisis. Cada archivo JSON en esta carpeta proporciona datos específicos sobre las características de los restaurantes, como su nombre, ubicación geográfica, tipo de cocina, horarios de atención, y otros detalles relevantes que permiten identificar y comparar a cada establecimiento dentro del mercado.
#
# **2. Carpeta: Review-Estados**
#
# La carpeta Review-Estados contiene una colección organizada de reseñas de clientes, separadas por estado, en formato JSON. Dentro de esta carpeta, cada subcarpeta representa un estado de la costa este de Estados Unidos, y a su vez, cada subcarpeta contiene múltiples archivos JSON que recogen las opiniones y calificaciones de los usuarios sobre los restaurantes. Estos archivos de reseñas capturan datos cruciales como la fecha de la reseña, la calificación otorgada, los comentarios detallados de los clientes, y otros atributos relevantes como el número de "me gusta" que ha recibido cada reseña.

# %% [markdown]
# **BIBLIOTECAS UTILIZADAS**

# %%
import pandas as pd
import re
import glob
import os
import pyarrow as pa
import pyarrow.parquet as pq
import json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import Counter
import nltk
from nltk.corpus import stopwords

# %% [markdown]
# ### **1.1 Metadata-Sitios**
#
# Se cargan los archivos .json y se concatenan en un mismo Dataframe

# %%
# Ruta del directorio que contiene los archivos JSON
ruta_directorio = './Datasets/Google/metadata-sitios/'

# Usamos glob para encontrar todos los archivos .json en el directorio
archivos_json = glob.glob(os.path.join(ruta_directorio, '*.json'))

# Lista para almacenar los DataFrames de cada archivo
dfs = []

# Iteramos sobre cada archivo JSON encontrado
for archivo in archivos_json:
    # Cargamos el archivo JSON en un DataFrame
    df_temp = pd.read_json(archivo, lines=True)
    
    # Agregamos el DataFrame a la lista
    dfs.append(df_temp)

# Combinamos todos los DataFrames en uno solo
df_final = pd.concat(dfs, ignore_index=True)

# Mostramos el tamaño del DataFrame combinado
print(f"Tamaño del DataFrame Metadata-Sitios combinado: {df_final.shape}")
# Out:
# Tamaño del DataFrame Metadata-Sitios combinado: (3025011, 15)

# %% [markdown]
# **Eliminar columnas**

# %% [markdown]
# Debido a que estos tipos de datos no son necesarios para nuestro análisis, se eliminarán las siguientes columnas: 'description', 'MISC', 'state', 'relative_results', 'url'.

# %%
# Eliminamos las columnas especificadas del DataFrame
columnas_a_eliminar = ['description', 'MISC', 'state', 'relative_results', 'url']
df_final = df_final.drop(columns=columnas_a_eliminar)

# %%
# Verificamos el resultado mostrando las primeras filas
df_final.head(3)
# Out:
#               name                                            address  \
# 0  Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1     City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2     San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
#
#                                  gmap_id   latitude  longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8  32.388300  -83.35710
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9  34.018891 -118.21529
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49  34.058092 -118.29213
#
#               category  avg_rating  num_of_reviews price  \
# 0           [Pharmacy]         4.9              16  None
# 1   [Textile exporter]         4.5               6  None
# 2  [Korean restaurant]         4.4              18  None
#
#                                                hours
# 0  [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...
# 1                                               None
# 2  [[Thursday, 6:30AM–6PM], [Friday, 6:30AM–6PM],...

# %% [markdown]
# De acuerdo a la dirección en la columna "address", se crea la Columna "estado", que nos da el estado del local comercial. Se hace porque nuestro dataset contiene todos los comercios del país, y el análisis será solo sobre la costa Este del mismo.

# %%
# Usamos una expresión regular para extraer el estado (dos letras antes del código postal)
df_final['estado'] = df_final['address'].str.extract(r',\s*([A-Z]{2})\s*\d{5}')

# Verificamos que la nueva columna 'estado' se ha creado correctamente
df_final[['address', 'estado']].head()
# Out:
#                                              address estado
# 0  Porter Pharmacy, 129 N Second St, Cochran, GA ...     GA
# 1  City Textile, 3001 E Pico Blvd, Los Angeles, C...     CA
# 2  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...     CA
# 3  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...     CA
# 4  Nobel Textile Co, 719 E 9th St, Los Angeles, C...     CA

# %% [markdown]
# Se eliminan las filas de los comercios que no están en la costa este del país.

# %%
# Lista de los estados que queremos conservar de la costa este
estados_deseados = [
    'ME',  # Maine
    'NH',  # New Hampshire
    'MA',  # Massachusetts
    'RI',  # Rhode Island
    'CT',  # Connecticut
    'NY',  # New York
    'NJ',  # New Jersey
    'DE',  # Delaware
    'MD',  # Maryland
    'VA',  # Virginia
    'NC',  # North Carolina
    'SC',  # South Carolina
    'GA',  # Georgia
    'FL'   # Florida
]

# %%
# Filtramos el DataFrame para que solo queden las filas con los estados deseados
df_metadata_ce = df_final[df_final['estado'].isin(estados_deseados)]

# Verificamos que el filtrado se haya realizado correctamente
print(df_metadata_ce[['address', 'estado']].head())
print(f"Tamaño del DataFrame después del filtrado: {df_metadata_ce.shape}")
# Out:
#                                               address estado
# 0   Porter Pharmacy, 129 N Second St, Cochran, GA ...     GA
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...     FL
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...     FL
# 56  Seminole Family Restaurant, 6864 Seminole Blvd...     FL
# 58  A-Top Insurance, 1009 Brighton Beach Ave, Broo...     NY
# Tamaño del DataFrame después del filtrado: (946582, 11)

# %%
df_metadata_ce.head(3)
# Out:
#                              name  \
# 0                 Porter Pharmacy
# 14                    NTK OUTDOOR
# 45  Cruises Inc. - Connie Stewart
#
#                                               address  \
# 0   Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
#
#                                   gmap_id   latitude  longitude  \
# 0   0x88f16e41928ff687:0x883dad4fd048e8f8  32.388300 -83.357100
# 14   0x88d9beb4fe0532c1:0xef0555c169299d6  25.795204 -80.366038
# 45  0x88c2e49b79f06c31:0x4ed8c8ce27e926e0  27.832187 -82.704805
#
#               category  avg_rating  num_of_reviews price  \
# 0           [Pharmacy]         4.9              16  None
# 14  [Corporate office]         5.0              35  None
# 45     [Cruise agency]         5.0               2  None
#
#                                                 hours estado
# 0   [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...     GA
# 14  [[Thursday, 9AM–6PM], [Friday, 9AM–6PM], [Satu...     FL
# 45  [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...     FL

# %% [markdown]
# Se agrega una nueva columna con el nombre completo del estado

# %%
# Diccionario de mapeo de abreviaturas a nombres completos de estados
mapa_estados = {
    'ME': 'Maine',
    'NH': 'New Hampshire',
    'MA': 'Massachusetts',
    'RI': 'Rhode Island',
    'CT': 'Connecticut',
    'NY': 'New York',
    'NJ': 'New Jersey',
    'DE': 'Delaware',
    'MD': 'Maryland',
    'VA': 'Virginia',
    'NC': 'North Carolina',
    'SC': 'South Carolina',
    'GA': 'Georgia',
    'FL': 'Florida'
}

# Creamos la nueva columna 'nombre_estado' usando el mapeo
df_metadata_ce['nombre_estado'] = df_metadata_ce['estado'].map(mapa_estados)

# Verificamos que la nueva columna se haya creado correctamente
print(df_metadata_ce[['estado', 'nombre_estado']].head())
# Out:
#    estado nombre_estado
# 0      GA       Georgia
# 14     FL       Florida
# 45     FL       Florida
# 56     FL       Florida
# 58     NY      New York
# C:\Users\54370\AppData\Local\Temp\ipykernel_10024\2111716646.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metadata_ce['nombre_estado'] = df_metadata_ce['estado'].map(mapa_estados)

# %%
# Mostramos el tamaño del DataFrame combinado
print(f"Tamaño del DataFrame combinado: {df_metadata_ce.shape}")
# Out:
# Tamaño del DataFrame combinado: (946582, 12)

# %% [markdown]
# Se exporta el dataframe a parquet para que su tamaño sea menor y su  velocidad de procesamiento sea mayor.

# %%
# Guardamos el DataFrame con la nueva columna en un archivo Parquet
df_metadata_ce.to_parquet('Datasets/Google/metadata-sitios/metadata-sitios-costaeste.parquet')

# %%
df_metadata_ce.head(3)
# Out:
#                              name  \
# 0                 Porter Pharmacy
# 14                    NTK OUTDOOR
# 45  Cruises Inc. - Connie Stewart
#
#                                               address  \
# 0   Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
#
#                                   gmap_id   latitude  longitude  \
# 0   0x88f16e41928ff687:0x883dad4fd048e8f8  32.388300 -83.357100
# 14   0x88d9beb4fe0532c1:0xef0555c169299d6  25.795204 -80.366038
# 45  0x88c2e49b79f06c31:0x4ed8c8ce27e926e0  27.832187 -82.704805
#
#               category  avg_rating  num_of_reviews price  \
# 0           [Pharmacy]         4.9              16  None
# 14  [Corporate office]         5.0              35  None
# 45     [Cruise agency]         5.0               2  None
#
#                                                 hours estado nombre_estado
# 0   [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...     GA       Georgia
# 14  [[Thursday, 9AM–6PM], [Friday, 9AM–6PM], [Satu...     FL       Florida
# 45  [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...     FL       Florida

# %% [markdown]
# Se carga el parquet porque la velocidad de procesamiento aumentará de manera significativa y para posteriormente realizar la limpieza de datos que serán utlizados.

# %%
# Especificamos la ruta de tu archivo Parquet
ruta_archivo = 'Datasets/Google/metadata-sitios/metadata-sitios-costaeste.parquet'

# Cargamos el archivo Parquet en un DataFrame
df = pd.read_parquet(ruta_archivo)

# Mostramos las primeras filas del DataFrame
df.head(3)
# Out:
#                              name  \
# 0                 Porter Pharmacy
# 14                    NTK OUTDOOR
# 45  Cruises Inc. - Connie Stewart
#
#                                               address  \
# 0   Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
#
#                                   gmap_id   latitude  longitude  \
# 0   0x88f16e41928ff687:0x883dad4fd048e8f8  32.388300 -83.357100
# 14   0x88d9beb4fe0532c1:0xef0555c169299d6  25.795204 -80.366038
# 45  0x88c2e49b79f06c31:0x4ed8c8ce27e926e0  27.832187 -82.704805
#
#               category  avg_rating  num_of_reviews price  \
# 0           [Pharmacy]         4.9              16  None
# 14  [Corporate office]         5.0              35  None
# 45     [Cruise agency]         5.0               2  None
#
#                                                 hours estado nombre_estado
# 0   [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...     GA       Georgia
# 14  [[Thursday, 9AM–6PM], [Friday, 9AM–6PM], [Satu...     FL       Florida
# 45  [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...     FL       Florida

# %%
df
# Out:
#                                   name  \
# 0                      Porter Pharmacy
# 14                         NTK OUTDOOR
# 45       Cruises Inc. - Connie Stewart
# 56          Seminole Family Restaurant
# 58                     A-Top Insurance
# ...                                ...
# 3024967     SVS Vision Optical Centers
# 3024968                 Express Liquor
# 3024969    Allstar Collision and Paint
# 3024976       House of Gourmet -- 食全食美
# 3024991                   Fedex Ground
#
#                                                    address  \
# 0        Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 14       NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45       Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
# 56       Seminole Family Restaurant, 6864 Seminole Blvd...
# 58       A-Top Insurance, 1009 Brighton Beach Ave, Broo...
# ...                                                    ...
# 3024967  SVS Vision Optical Centers, 1551 Niagara Falls...
# 3024968  Express Liquor, 6589 Thompson Rd suite b, Syra...
# 3024969  Allstar Collision and Paint, 6050 Sheridan Dr,...
# 3024976  House of Gourmet -- 食全食美, 2865 Sheridan Dr Sui...
# 3024991       Fedex Ground, Fedex Dr, Middletown, CT 06457
#
#                                        gmap_id   latitude  longitude  \
# 0        0x88f16e41928ff687:0x883dad4fd048e8f8  32.388300 -83.357100
# 14        0x88d9beb4fe0532c1:0xef0555c169299d6  25.795204 -80.366038
# 45       0x88c2e49b79f06c31:0x4ed8c8ce27e926e0  27.832187 -82.704805
# 56       0x88c2fb8614e57ce9:0x40b51628875ad6e9  27.834885 -82.787419
# 58       0x89c24469c758686b:0x641f5b84cb9bedfa  40.578254 -73.959127
# ...                                        ...        ...        ...
# 3024967  0x89d3721399f576df:0xe572aaa0d5ae28fc  42.997026 -78.821580
# 3024968   0x89d9f2a96ec09509:0xc8d86190079d033  43.088776 -76.092804
# 3024969  0x89d3744be13dc5f5:0x22f97178c788cb06  42.978248 -78.707804
# 3024976   0x89d373386b718fff:0xf82c90ef48e7b23  42.980251 -78.827337
# 3024991  0x89e7b5d5a1f83707:0xf3856c7e5901d16d  41.598762 -72.716026
#
#                                                   category  avg_rating  \
# 0                                               [Pharmacy]         4.9
# 14                                      [Corporate office]         5.0
# 45                                         [Cruise agency]         5.0
# 56                                                    None         3.6
# 58                    [Insurance broker, Insurance agency]         2.0
# ...                                                    ...         ...
# 3024967  [Eye care center, Contact lenses supplier, Opt...         4.7
# 3024968                                     [Liquor store]         3.5
# 3024969  [Auto body shop, Auto dent removal service, Ca...         5.0
# 3024976           [Chinese restaurant, Sichuan restaurant]         4.3
# 3024991                                 [Corporate office]         4.3
#
#          num_of_reviews price  \
# 0                    16  None
# 14                   35  None
# 45                    2  None
# 56                    8    $$
# 58                    4  None
# ...                 ...   ...
# 3024967              68  None
# 3024968               8  None
# 3024969              48  None
# 3024976              58  None
# 3024991               8  None
#
#                                                      hours estado  \
# 0        [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...     GA
# 14       [[Thursday, 9AM–6PM], [Friday, 9AM–6PM], [Satu...     FL
# 45       [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...     FL
# 56                                                    None     FL
# 58       [[Thursday, 10AM–6PM], [Friday, 10AM–6PM], [Sa...     NY
# ...                                                    ...    ...
# 3024967  [[Saturday, 9AM–1PM], [Sunday, Closed], [Monda...     NY
# 3024968  [[Saturday, 10AM–10PM], [Sunday, 12–6PM], [Mon...     NY
# 3024969  [[Saturday, Closed], [Sunday, Closed], [Monday...     NY
# 3024976  [[Saturday, 11:15AM–9:45PM], [Sunday, 11:15AM–...     NY
# 3024991  [[Saturday, Open 24 hours], [Sunday, Open 24 h...     CT
#
#         nombre_estado
# 0             Georgia
# 14            Florida
# 45            Florida
# 56            Florida
# 58           New York
# ...               ...
# 3024967      New York
# 3024968      New York
# 3024969      New York
# 3024976      New York
# 3024991   Connecticut
#
# [946582 rows x 12 columns]

# %% [markdown]
# Se crea la columna ciudad de acuerdo a la columna "address" para ser utlizada posteriormente en el análisis de datos.

# %%
# Utilizamos una expresión regular para extraer la ciudad, que se encuentra entre la dirección y el estado
df['city'] = df['address'].str.extract(r',\s*([^,]+),\s*[A-Z]{2}\s*\d{5}')

# Mostramos las primeras filas para verificar
df[['address', 'city']].head()
# Out:
#                                               address           city
# 0   Porter Pharmacy, 129 N Second St, Cochran, GA ...        Cochran
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...          Miami
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...  Pinellas Park
# 56  Seminole Family Restaurant, 6864 Seminole Blvd...       Seminole
# 58  A-Top Insurance, 1009 Brighton Beach Ave, Broo...       Brooklyn

# %%
df
# Out:
#                                   name  \
# 0                      Porter Pharmacy
# 14                         NTK OUTDOOR
# 45       Cruises Inc. - Connie Stewart
# 56          Seminole Family Restaurant
# 58                     A-Top Insurance
# ...                                ...
# 3024967     SVS Vision Optical Centers
# 3024968                 Express Liquor
# 3024969    Allstar Collision and Paint
# 3024976       House of Gourmet -- 食全食美
# 3024991                   Fedex Ground
#
#                                                    address  \
# 0        Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 14       NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45       Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
# 56       Seminole Family Restaurant, 6864 Seminole Blvd...
# 58       A-Top Insurance, 1009 Brighton Beach Ave, Broo...
# ...                                                    ...
# 3024967  SVS Vision Optical Centers, 1551 Niagara Falls...
# 3024968  Express Liquor, 6589 Thompson Rd suite b, Syra...
# 3024969  Allstar Collision and Paint, 6050 Sheridan Dr,...
# 3024976  House of Gourmet -- 食全食美, 2865 Sheridan Dr Sui...
# 3024991       Fedex Ground, Fedex Dr, Middletown, CT 06457
#
#                                        gmap_id   latitude  longitude  \
# 0        0x88f16e41928ff687:0x883dad4fd048e8f8  32.388300 -83.357100
# 14        0x88d9beb4fe0532c1:0xef0555c169299d6  25.795204 -80.366038
# 45       0x88c2e49b79f06c31:0x4ed8c8ce27e926e0  27.832187 -82.704805
# 56       0x88c2fb8614e57ce9:0x40b51628875ad6e9  27.834885 -82.787419
# 58       0x89c24469c758686b:0x641f5b84cb9bedfa  40.578254 -73.959127
# ...                                        ...        ...        ...
# 3024967  0x89d3721399f576df:0xe572aaa0d5ae28fc  42.997026 -78.821580
# 3024968   0x89d9f2a96ec09509:0xc8d86190079d033  43.088776 -76.092804
# 3024969  0x89d3744be13dc5f5:0x22f97178c788cb06  42.978248 -78.707804
# 3024976   0x89d373386b718fff:0xf82c90ef48e7b23  42.980251 -78.827337
# 3024991  0x89e7b5d5a1f83707:0xf3856c7e5901d16d  41.598762 -72.716026
#
#                                                   category  avg_rating  \
# 0                                               [Pharmacy]         4.9
# 14                                      [Corporate office]         5.0
# 45                                         [Cruise agency]         5.0
# 56                                                    None         3.6
# 58                    [Insurance broker, Insurance agency]         2.0
# ...                                                    ...         ...
# 3024967  [Eye care center, Contact lenses supplier, Opt...         4.7
# 3024968                                     [Liquor store]         3.5
# 3024969  [Auto body shop, Auto dent removal service, Ca...         5.0
# 3024976           [Chinese restaurant, Sichuan restaurant]         4.3
# 3024991                                 [Corporate office]         4.3
#
#          num_of_reviews price  \
# 0                    16  None
# 14                   35  None
# 45                    2  None
# 56                    8    $$
# 58                    4  None
# ...                 ...   ...
# 3024967              68  None
# 3024968               8  None
# 3024969              48  None
# 3024976              58  None
# 3024991               8  None
#
#                                                      hours estado  \
# 0        [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...     GA
# 14       [[Thursday, 9AM–6PM], [Friday, 9AM–6PM], [Satu...     FL
# 45       [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...     FL
# 56                                                    None     FL
# 58       [[Thursday, 10AM–6PM], [Friday, 10AM–6PM], [Sa...     NY
# ...                                                    ...    ...
# 3024967  [[Saturday, 9AM–1PM], [Sunday, Closed], [Monda...     NY
# 3024968  [[Saturday, 10AM–10PM], [Sunday, 12–6PM], [Mon...     NY
# 3024969  [[Saturday, Closed], [Sunday, Closed], [Monday...     NY
# 3024976  [[Saturday, 11:15AM–9:45PM], [Sunday, 11:15AM–...     NY
# 3024991  [[Saturday, Open 24 hours], [Sunday, Open 24 h...     CT
#
#         nombre_estado           city
# 0             Georgia        Cochran
# 14            Florida          Miami
# 45            Florida  Pinellas Park
# 56            Florida       Seminole
# 58           New York       Brooklyn
# ...               ...            ...
# 3024967      New York        Buffalo
# 3024968      New York       Syracuse
# 3024969      New York        Buffalo
# 3024976      New York      Tonawanda
# 3024991   Connecticut     Middletown
#
# [946582 rows x 13 columns]

# %%
# Guardamos el DataFrame con la nueva columna en un archivo Parquet
df.to_parquet('Datasets/Google/metadata-sitios/metadata-sitios-costaeste-estado-ciudad.parquet')

# %% [markdown]
# ### **Creación de los archivos parquet de Reviews-Estados de Google maps**

# %%
# Función para procesar la carga de datos
def procesar_archivos_json(ruta_directorio, nombre_estado, columnas_a_eliminar=['pics', 'resp']):
    # Usamos glob para encontrar todos los archivos .json en el directorio
    archivos_json = glob.glob(os.path.join(ruta_directorio, '*.json'))
    
    # Lista para almacenar los DataFrames de cada archivo
    dfs = []

    # Iteramos sobre cada archivo JSON encontrado
    for archivo in archivos_json:
        # Cargamos el archivo JSON en un DataFrame
        df_temp = pd.read_json(archivo, lines=True)
        
        # Agregamos el DataFrame a la lista
        dfs.append(df_temp)

    # Combinamos todos los DataFrames en uno solo
    df_combinado = pd.concat(dfs, ignore_index=True)

    # Mostramos el tamaño del DataFrame combinado
    print(f"Tamaño del DataFrame combinado para {nombre_estado}: {df_combinado.shape}")

    # Eliminamos las columnas especificadas del DataFrame
    df_combinado = df_combinado.drop(columns=columnas_a_eliminar)

    # Guardamos el DataFrame en un archivo Parquet
    ruta_salida = f'Datasets/Google/review-estados/review-estados-parquet/review-{nombre_estado.lower()}.parquet'
    df_combinado.to_parquet(ruta_salida)
    
    print(f"Archivo Parquet guardado en: {ruta_salida}")
    
    return df_combinado

# %% [markdown]
# **01. Estado de la Florida**

# %%
df_florida = procesar_archivos_json('./Datasets/Google/review-estados/review-Florida', 'Florida')
# Out:
# Tamaño del DataFrame combinado para Florida: (2850000, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-florida.parquet

# %% [markdown]
# **02. Estado de Georgia**

# %%
df_georgia = procesar_archivos_json('./Datasets/Google/review-estados/review-Georgia', 'Georgia')
# Out:
# Tamaño del DataFrame combinado para Georgia: (1950000, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-georgia.parquet

# %% [markdown]
# **03. Estado de North Carolina**

# %%
df_north_carolina = procesar_archivos_json('./Datasets/Google/review-estados/review-North_Carolina', 'North_Carolina')
# Out:
# Tamaño del DataFrame combinado para North_Carolina: (2250000, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-north_carolina.parquet

# %% [markdown]
# **04. Estado de South Carolina**

# %%
df_south_carolina = procesar_archivos_json('./Datasets/Google/review-estados/review-South_Carolina', 'South_Carolina')
# Out:
# Tamaño del DataFrame combinado para South_Carolina: (2100000, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-south_carolina.parquet

# %% [markdown]
# **05. Estado de Maine**

# %%
df_maine = procesar_archivos_json('./Datasets/Google/review-estados/review-Maine', 'Maine')
# Out:
# Tamaño del DataFrame combinado para Maine: (1123881, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-maine.parquet

# %% [markdown]
# **06. Estado de Massachusetts**

# %%
df_maine = procesar_archivos_json('./Datasets/Google/review-estados/review-Massachusetts', 'Massachusetts')
# Out:
# Tamaño del DataFrame combinado para Massachusetts: (2400000, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-massachusetts.parquet

# %% [markdown]
# **07. Estado de New Hampshire**

# %%
df_new_hampshire = procesar_archivos_json('./Datasets/Google/review-estados/review-New_Hampshire', 'New_Hampshire')
# Out:
# Tamaño del DataFrame combinado para New_Hampshire: (1296603, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-new_hampshire.parquet

# %% [markdown]
# **08.Estado de Rhode Island**

# %%
df_rhode_island = procesar_archivos_json('./Datasets/Google/review-estados/review-Rhode_Island', 'Rhode_Island')
# Out:
# Tamaño del DataFrame combinado para Rhode_Island: (890006, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-rhode_island.parquet

# %% [markdown]
# **09. Estado de New York**

# %%
df_new_york = procesar_archivos_json('./Datasets/Google/review-estados/review-New_York', 'New_York')
# Out:
# Tamaño del DataFrame combinado para New_York: (2700000, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-new_york.parquet

# %% [markdown]
# **10. Estado de Connecticut**

# %%
df_connecticut = procesar_archivos_json('./Datasets/Google/review-estados/review-Connecticut', 'Connecticut')
# Out:
# Tamaño del DataFrame combinado para Connecticut: (2680107, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-connecticut.parquet

# %% [markdown]
# **11. Estado de Delaware**

# %%
df_delaware = procesar_archivos_json('./Datasets/Google/review-estados/review-Delaware', 'Delaware')
# Out:
# Tamaño del DataFrame combinado para Delaware: (905537, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-delaware.parquet

# %% [markdown]
# **12. Estado de New Jersey**

# %%
df_new_jersey = procesar_archivos_json('./Datasets/Google/review-estados/review-New_Jersey', 'New_Jersey')
# Out:
# Tamaño del DataFrame combinado para New_Jersey: (1950000, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-new_jersey.parquet

# %% [markdown]
# **13. Estado de Maryland**

# %%
df_maryland = procesar_archivos_json('./Datasets/Google/review-estados/review-Maryland', 'Maryland')
# Out:
# Tamaño del DataFrame combinado para Maryland: (2400000, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-maryland.parquet

# %% [markdown]
# **14. Estado de Virginia**

# %%
df_virginia = procesar_archivos_json('./Datasets/Google/review-estados/review-Virginia', 'Virginia')
# Out:
# Tamaño del DataFrame combinado para Virginia: (1662059, 8)
# Archivo Parquet guardado en: Datasets/Google/review-estados/review-estados-parquet/review-virginia.parquet

# %% [markdown]
# ### **2. Carga de datos Yelp**
#
# **Descripción de los Datos de Yelp**
#
# Para el análisis de la cadena de restaurantes China Garden en la costa este de Estados Unidos, se han recopilado datos detallados de Yelp, una de las plataformas de reseñas de restaurantes más importantes. Estos datos se encuentran distribuidos en cinco archivos distintos, cada uno de los cuales proporciona información relevante para entender el comportamiento del mercado y la percepción de los consumidores.
#
# **1. Archivo: business.pkl**
#
# El archivo business.pkl contiene información esencial sobre los negocios listados en Yelp, específicamente sobre los restaurantes de interés. Este archivo proporciona datos detallados de cada establecimiento, incluyendo su nombre, dirección, categoría, atributos adicionales (como si ofrece opciones vegetarianas o si tiene estacionamiento), y su ubicación geográfica exacta. Estos datos son fundamentales para realizar un análisis geoespacial, identificar patrones en las ubicaciones de los restaurantes, y comparar características de los competidores dentro del mismo mercado.
#
# **2. Archivo: Checkin.json**
#
# El archivo Checkin.json proporciona los datos de horarios de reservas y registros de visitas de los usuarios a los restaurantes. Este archivo permite analizar las horas pico de actividad, la popularidad de los restaurantes en diferentes días de la semana, y la frecuencia de visitas de los clientes. Este análisis es crucial para entender los patrones de tráfico y comportamiento de los consumidores, lo que puede ayudar a optimizar los horarios de operación y estrategias de marketing.
#
# **3. Archivo: Review.json**
#
# El archivo Review.json contiene las reseñas de los clientes que han visitado los restaurantes de interés. Cada reseña incluye información valiosa como la calificación otorgada (de 1 a 5 estrellas), el texto de la reseña, la fecha en que se escribió, y otros atributos que reflejan la experiencia del cliente. Este archivo es fundamental para realizar un análisis de sentimientos y evaluar las opiniones de los consumidores sobre China Garden y sus competidores. Además, permite identificar temas recurrentes en los comentarios de los clientes, puntos fuertes, áreas de mejora, y tendencias emergentes en la percepción del mercado.
#
# **4. Archivo: Tip**
#
# El archivo Tip contiene una recopilación de recomendaciones o consejos breves que los usuarios han dejado sobre los restaurantes en Yelp. Aunque estos "tips" son más cortos que las reseñas tradicionales, a menudo proporcionan insights rápidos y directos sobre lo que los clientes consideran relevante o digno de destacar. Este archivo permite complementar el análisis de reseñas con datos adicionales que pueden ayudar a identificar las expectativas y preferencias de los clientes.
#
# **5. Archivo: User**
#
# El archivo User proporciona información sobre los usuarios de Yelp que han interactuado con los restaurantes de la cadena y sus competidores. Incluye detalles como el número total de reseñas realizadas por cada usuario, su ubicación, el promedio de calificaciones otorgadas, y otros comportamientos del usuario en la plataforma. Este archivo es clave para identificar clientes leales, entender los perfiles demográficos y de comportamiento de los clientes, y determinar cómo interactúan diferentes grupos de consumidores con los restaurantes de interés.
#
# **Proceso de Preparación de los Dato**s
# Para realizar un análisis integral, se procederá con la limpieza y unificación de los datos de cada archivo:
#
# Integración de la información de negocios del archivo business.pkl con los datos de los archivos de reseñas, tips, check-ins y usuarios.
# Procesamiento de los archivos JSON para extraer insights relevantes sobre la actividad de los clientes, patrones de reserva, y calificaciones.
# Análisis combinado de los datos de Yelp para identificar oportunidades de mejora y estrategias de crecimiento para "China Garden" en la costa este de Estados Unidos.
# Esta estructura de datos permitirá llevar a cabo un análisis exhaustivo que considere no solo la competencia y el posicionamiento actual de "China Garden", sino también las expectativas y percepciones de los clientes en tiempo real.

# %% [markdown]
# ### **01. Carga y exportación a parquet del archivo Bussiness.pkl**

# %%
# Ruta al archivo .pkl
ruta_archivo = 'Datasets/Yelp/business.pkl'

# Cargamos el archivo .pkl en un DataFrame
df = pd.read_pickle(ruta_archivo)

# Mostramos las primeras filas del DataFrame para verificar que se haya cargado correctamente
df.head(3)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# 2  32.223236 -110.880452   3.5           22  ...   NaN         NaN      NaN
#
#   longitude stars review_count is_open attributes categories hours
# 0       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 1       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# 2       NaN   NaN          NaN     NaN        NaN        NaN   NaN
#
# [3 rows x 28 columns]

# %%
# Exploración de columnas
df.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours', 'business_id', 'name', 'address',
#        'city', 'state', 'postal_code', 'latitude', 'longitude', 'stars',
#        'review_count', 'is_open', 'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
df.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %% [markdown]
# Se encontraron varias columnas duplicadas

# %%
# Eliminamos columnas duplicadas
df = df.loc[:, ~df.columns.duplicated()]

# Mostramos las columnas después de eliminar duplicados
df.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
df.shape
# Out:
# (150346, 14)

# %%
# Eliminamos las columnas especificadas del DataFrame
columnas_a_eliminar = ['address', 'is_open', 'attributes', 'hours']
df = df.drop(columns=columnas_a_eliminar)

df.shape
# Out:
# (150346, 10)

# %% [markdown]
# Se filtra el DataFrame por estados de la costa este

# %%
# Lista de estados de la costa este que queremos mantener
east_coast_states = ['ME', 'NH', 'MA', 'RI', 'CT', 'NY', 'NJ', 'DE', 'MD', 'VA', 'NC', 'SC', 'GA', 'FL']

# Filtramos el DataFrame para eliminar los valores nulos en la columna 'state' 
# y mantenemos solo los estados de la costa este
df_filtrado = df[df['state'].isin(east_coast_states) & df['state'].notna()]

# Mostramos el DataFrame filtrado
df_filtrado.head(3)
# Out:
#                business_id                  name           city state  \
# 10  UJsufbvfyfONHeWdvAHKjA             Marshalls  Land O' Lakes    FL
# 13  jaxMSoInw8Poo3XeMJt8lQ          Adams Dental     Clearwater    FL
# 14  0bPLkL0QhhPO5kt1_EXmNQ  Zio's Italian Market          Largo    FL
#
#    postal_code   latitude  longitude stars review_count  \
# 10       34639  28.190459  -82.45738   3.5            6
# 13       33755  27.966235 -82.787412   5.0           10
# 14       33771  27.916116 -82.760461   4.5          100
#
#                                            categories
# 10               Department Stores, Shopping, Fashion
# 13  General Dentistry, Dentists, Health & Medical,...
# 14        Food, Delis, Italian, Bakeries, Restaurants

# %%
df_filtrado.shape
# Out:
# (37133, 10)

# %% [markdown]
# Se agrega una columna con el nombre de estado completo

# %%
# Diccionario de códigos de estado a nombres completos
state_names = {
    'ME': 'Maine',
    'NH': 'New Hampshire',
    'MA': 'Massachusetts',
    'RI': 'Rhode Island',
    'CT': 'Connecticut',
    'NY': 'New York',
    'NJ': 'New Jersey',
    'DE': 'Delaware',
    'MD': 'Maryland',
    'VA': 'Virginia',
    'NC': 'North Carolina',
    'SC': 'South Carolina',
    'GA': 'Georgia',
    'FL': 'Florida'
}

# Creamos la nueva columna 'nombre_estado' utilizando el diccionario y el método .map()
df_filtrado['nombre_estado'] = df_filtrado['state'].map(state_names)

# Mostramos el DataFrame con la nueva columna
df_filtrado.head(3)
# Out:
# C:\Users\54370\AppData\Local\Temp\ipykernel_10024\2195659317.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['nombre_estado'] = df_filtrado['state'].map(state_names)
#                business_id                  name           city state  \
# 10  UJsufbvfyfONHeWdvAHKjA             Marshalls  Land O' Lakes    FL
# 13  jaxMSoInw8Poo3XeMJt8lQ          Adams Dental     Clearwater    FL
# 14  0bPLkL0QhhPO5kt1_EXmNQ  Zio's Italian Market          Largo    FL
#
#    postal_code   latitude  longitude stars review_count  \
# 10       34639  28.190459  -82.45738   3.5            6
# 13       33755  27.966235 -82.787412   5.0           10
# 14       33771  27.916116 -82.760461   4.5          100
#
#                                            categories nombre_estado
# 10               Department Stores, Shopping, Fashion       Florida
# 13  General Dentistry, Dentists, Health & Medical,...       Florida
# 14        Food, Delis, Italian, Bakeries, Restaurants       Florida

# %%
# Guardamos el DataFrame en un archivo Parquet
df_filtrado.to_parquet('Datasets/Yelp/parquet_files/Business.parquet')

# %% [markdown]
# ### **02. Carga y exportación a parquet del archivo Checkin.json**

# %%
#Ruta de tu archivo JSON 1
ruta_archivo = 'Datasets\Yelp\checkin.json'

# Cargamos el archivo JSON en un DataFrame de pandas usando lines=True
df = pd.read_json(ruta_archivo, lines=True)

# Mostramos el DataFrame
df.head(3)
# Out:
#               business_id                                               date
# 0  ---kPU91CF4Lq2-WlRu9Lw  2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1  --0iUa4sNDFiZFrAdIWhZQ  2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2  --30_8IhuyMHbSOcNWd6DQ           2013-06-14 23:29:17, 2014-08-13 23:20:22

# %%
# Guardamos el DataFrame en un archivo Parquet
df.to_parquet('Datasets/Yelp/parquet_files/Checkin.parquet')

# %% [markdown]
# ### **03. Carga y exportación a parquet del archivo review.json**

# %%
# Carga review.json
# Intentamos con utf-8
try:
    with open('Datasets/Yelp/review.json', 'r', encoding='utf-8') as f:
        df_review = pd.DataFrame([json.loads(line) for line in f])
except UnicodeDecodeError:
    # Si utf-8 falla, intentamos con utf-8-sig
    with open('Datasets/Yelp/review.json', 'r', encoding='utf-8-sig') as f:
        df_review = pd.DataFrame([json.loads(line) for line in f])

# %%
df_review.head(3)
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    5.0       1      0     1
# 2    3.0       0      0     0
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30

# %%
df_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    object
#  1   user_id      object
#  2   business_id  object
#  3   stars        float64
#  4   useful       int64
#  5   funny        int64
#  6   cool         int64
#  7   text         object
#  8   date         object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 480.0+ MB

# %%
# Eliminamos columnas innecesarias
df_review.drop(['useful', 'funny', 'cool'], axis=1, inplace=True)

# %%
# Exportamos a parquet
df_review.to_parquet('Datasets/Yelp/parquet_files/review-yelp.parquet', index=False)
# Out:
# ---------------------------------------------------------------------------
# ArrowMemoryError                          Traceback (most recent call last)
# Cell In[49], line 2
#       1 # Exportar a parquet
# ----> 2 df_review.to_parquet('Datasets/Yelp/parquet_files/review-yelp.parquet', index=False)
#
# File d:\PROYECTO FINAL\venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File d:\PROYECTO FINAL\venv\Lib\site-packages\pandas\core\frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)
#    3109 >>> content = f.read()
#    3110 """
#    3111 from pandas.io.parquet import to_parquet
# -> 3113 return to_parquet(
#    3114     self,
#    3115     path,
#    3116     engine,
#    3117     compression=compression,
#    3118     index=index,
#    3119     partition_cols=partition_cols,
#    3120     storage_options=storage_options,
#    3121     **kwargs,
#    3122 )
#
# File d:\PROYECTO FINAL\venv\Lib\site-packages\pandas\io\parquet.py:480, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 impl = get_engine(engine)
#     478 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 480 impl.write(
#     481     df,
#     482     path_or_buf,
#     483     compression=compression,
#     484     index=index,
#     485     partition_cols=partition_cols,
#     486     storage_options=storage_options,
#     487     filesystem=filesystem,
#     488     **kwargs,
#     489 )
#     491 if path is None:
#     492     assert isinstance(path_or_buf, io.BytesIO)
#
# File d:\PROYECTO FINAL\venv\Lib\site-packages\pandas\io\parquet.py:190, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     187 if index is not None:
#     188     from_pandas_kwargs["preserve_index"] = index
# --> 190 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     192 if df.attrs:
#     193     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File d:\PROYECTO FINAL\venv\Lib\site-packages\pyarrow\table.pxi:4623, in pyarrow.lib.Table.from_pandas()
#
# File d:\PROYECTO FINAL\venv\Lib\site-packages\pyarrow\pandas_compat.py:629, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     627     for i, maybe_fut in enumerate(arrays):
#     628         if isinstance(maybe_fut, futures.Future):
# --> 629             arrays[i] = maybe_fut.result()
#     631 types = [x.type for x in arrays]
#     633 if schema is None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File d:\PROYECTO FINAL\venv\Lib\site-packages\pyarrow\pandas_compat.py:597, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     594     type_ = field.type
#     596 try:
# --> 597     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     598 except (pa.ArrowInvalid,
#     599         pa.ArrowNotImplementedError,
#     600         pa.ArrowTypeError) as e:
#     601     e.args += ("Conversion failed for column {!s} with type {!s}"
#     602                .format(col.name, col.dtype),)
#
# File d:\PROYECTO FINAL\venv\Lib\site-packages\pyarrow\array.pxi:358, in pyarrow.lib.array()
#
# File d:\PROYECTO FINAL\venv\Lib\site-packages\pyarrow\array.pxi:85, in pyarrow.lib._ndarray_to_array()
#
# File d:\PROYECTO FINAL\venv\Lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowMemoryError: realloc of size 704643072 failed

# %% [markdown]
# ### **Se abre nuevamente business.parquet para mergear los 14 estados en el DataFrame "review"**

# %%
business = pd.read_parquet("Datasets/Yelp/parquet_files/Business.parquet")
review = pd.read_parquet('Datasets/Yelp/parquet_files/review-yelp.parquet')

# %%
merged_df = pd.merge(business, review, on='business_id', how='inner')

# %%
merged_df.shape
# Out:
# (1734757, 16)

# %%
merged_df.head(3)
# Out:
#               business_id       name           city state postal_code  \
# 0  UJsufbvfyfONHeWdvAHKjA  Marshalls  Land O' Lakes    FL       34639
# 1  UJsufbvfyfONHeWdvAHKjA  Marshalls  Land O' Lakes    FL       34639
# 2  UJsufbvfyfONHeWdvAHKjA  Marshalls  Land O' Lakes    FL       34639
#
#     latitude  longitude  stars_x  review_count  \
# 0  28.190459  -82.45738      3.5             6
# 1  28.190459  -82.45738      3.5             6
# 2  28.190459  -82.45738      3.5             6
#
#                              categories nombre_estado               review_id  \
# 0  Department Stores, Shopping, Fashion       Florida  MKf1btP1IWejTptigCLrSw
# 1  Department Stores, Shopping, Fashion       Florida  MxpvjOXWjyp3xPA6qJenKw
# 2  Department Stores, Shopping, Fashion       Florida  6dy2iBob-3lNlGVfdzXH_Q
#
#                   user_id  stars_y  \
# 0  u4Dzi_282Zw6hKqZJOhsSw      5.0
# 1  qjfMBIZpQT9DDtw_BWCopQ      4.0
# 2  F-OwSluUWMn0vMp3bPWMnQ      3.0
#
#                                                 text                 date
# 0  What's not to love about Marshalls?! I absolut...  2020-11-20 19:02:54
# 1  This is a nice Marshalls, and it is pretty new...  2015-07-24 00:31:29
# 2  I Have not been here in so many years that I f...  2019-10-18 17:43:01

# %% [markdown]
# **Se exporta a parquet reviews-yelp**

# %%
merged_df.to_parquet("Datasets/Yelp/parquet_files/review-yelp.parquet")

# %% [markdown]
# ### **Limpieza metadata_google**

# %%
df_metadata_google = pd.read_parquet('Datasets/Google/metadata-sitios/metadata-sitios-costaeste-estado-ciudad.parquet')
df_metadata_google.head(3)
# Out:
#                              name  \
# 0                 Porter Pharmacy
# 14                    NTK OUTDOOR
# 45  Cruises Inc. - Connie Stewart
#
#                                               address  \
# 0   Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
#
#                                   gmap_id   latitude  longitude  \
# 0   0x88f16e41928ff687:0x883dad4fd048e8f8  32.388300 -83.357100
# 14   0x88d9beb4fe0532c1:0xef0555c169299d6  25.795204 -80.366038
# 45  0x88c2e49b79f06c31:0x4ed8c8ce27e926e0  27.832187 -82.704805
#
#               category  avg_rating  num_of_reviews price  \
# 0           [Pharmacy]         4.9              16  None
# 14  [Corporate office]         5.0              35  None
# 45     [Cruise agency]         5.0               2  None
#
#                                                 hours estado nombre_estado  \
# 0   [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...     GA       Georgia
# 14  [[Thursday, 9AM–6PM], [Friday, 9AM–6PM], [Satu...     FL       Florida
# 45  [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...     FL       Florida
#
#              city
# 0         Cochran
# 14          Miami
# 45  Pinellas Park

# %%
df_metadata_google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 946582 entries, 0 to 3024991
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            946582 non-null  object
#  1   address         946582 non-null  object
#  2   gmap_id         946582 non-null  object
#  3   latitude        946582 non-null  float64
#  4   longitude       946582 non-null  float64
#  5   category        941305 non-null  object
#  6   avg_rating      946582 non-null  float64
#  7   num_of_reviews  946582 non-null  int64
#  8   price           91985 non-null   object
#  9   hours           710387 non-null  object
#  10  estado          946582 non-null  object
#  11  nombre_estado   946582 non-null  object
#  12  city            945910 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 101.1+ MB

# %%
# Chequeo de duplicados en gmap_id
df_metadata_google.duplicated('gmap_id').sum()
# Out:
# np.int64(8345)

# %%
duplicados = df_metadata_google[df_metadata_google.duplicated(subset='gmap_id', keep=False)]
conteo = df_metadata_google['gmap_id'].value_counts()
repetidos = conteo[conteo > 1]

print(repetidos)
# Out:
# gmap_id
# 0x88f16e41928ff687:0x883dad4fd048e8f8    12
# 0x884d0db9065bd815:0xae8443b860eebe8e     2
# 0x89e841975461fb8f:0x16df15574a663326     2
# 0x88f5993c9c7382fd:0xfd57cf3b5826d3b9     2
# 0x88d9beb4fe0532c1:0xef0555c169299d6      2
#                                          ..
# 0x88d9a4e66e40edf1:0xebbab577da8076fe     2
# 0x88d9aa92d831c45b:0x9b14ae9ded185345     2
# 0x88d9a67325994b17:0xdac6d8d4600fc268     2
# 0x88d9b937c540e7d7:0xc36f9d9593ca9008     2
# 0x4cb29c6a0460a84b:0x243771cbbefd58d9     2
# Name: count, Length: 8335, dtype: int64

# %%
# Eliminamos duplicados del DF columna gmap_id
df_metadata_google = df_metadata_google.drop_duplicates(subset=['gmap_id'])

# %%
# Chequeo de duplicados en gmap_id
df_metadata_google.duplicated('gmap_id').sum()
# Out:
# np.int64(0)

# %%
# Chequeo de datos nulos en el DF
df_metadata_google.isnull().sum()
# Out:
# name                   0
# address                0
# gmap_id                0
# latitude               0
# longitude              0
# category            5212
# avg_rating             0
# num_of_reviews         0
# price             846698
# hours             233791
# estado                 0
# nombre_estado          0
# city                 668
# dtype: int64

# %% [markdown]
# Se borran las columnas "price" y "hours"

# %%
# Eliminamos las columnas especificadas del DataFrame
columnas_a_eliminar = ['price', 'hours']
df_metadata_google = df_metadata_google.drop(columns=columnas_a_eliminar)

# %% [markdown]
# Se eliminan filas con categorías nulas

# %%
df_metadata_google= df_metadata_google.dropna(subset=['category'])

# %% [markdown]
# Columna city contiene 667 nulos... ubicar por latitud y longitud ???

# %%
# Filtrar las filas con valores nulos en la columna 'city'
filas_con_city_nulo = df_metadata_google[df_metadata_google['city'].isnull()]

# Contar las ocurrencias de cada categoría para estas filas
categorias_con_city_nulo = filas_con_city_nulo['category'].value_counts()

# Imprimir los resultados
print("Categorías de las filas con valores nulos en 'city':")
for categoria, cantidad in categorias_con_city_nulo.items():
    print(f"Categoría: {categoria}, Cantidad de nulos: {cantidad}")

# Imprimir el total de filas con 'city' nulo
print(f"\nTotal de filas con 'city' nulo: {len(filas_con_city_nulo)}")
# Out:
# Categorías de las filas con valores nulos en 'city':
# Categoría: ['Lake'], Cantidad de nulos: 276
# Categoría: ['Wetland'], Cantidad de nulos: 197
# Categoría: ['Train station'], Cantidad de nulos: 67
# Categoría: ['River'], Cantidad de nulos: 37
# Categoría: ['Canal'], Cantidad de nulos: 12
# Categoría: ['Bus stop'], Cantidad de nulos: 10
# Categoría: ['Beach'], Cantidad de nulos: 10
# Categoría: ['Pond'], Cantidad de nulos: 8
# Categoría: ['Island'], Cantidad de nulos: 8
# Categoría: ['Reservoir'], Cantidad de nulos: 6
# Categoría: ['Ferry terminal'], Cantidad de nulos: 5
# Categoría: ['Peninsula'], Cantidad de nulos: 3
# Categoría: ['Lodging'], Cantidad de nulos: 3
# Categoría: ['Park'], Cantidad de nulos: 2
# Categoría: ['Bus station'], Cantidad de nulos: 2
# Categoría: ['Spring'], Cantidad de nulos: 2
# Categoría: ['Water'], Cantidad de nulos: 2
# Categoría: ['Beach pavillion'], Cantidad de nulos: 2
# Categoría: ['Beach volleyball court'], Cantidad de nulos: 1
# Categoría: ['Light rail station'], Cantidad de nulos: 1
# Categoría: ['Tourist attraction'], Cantidad de nulos: 1
# Categoría: ['Halfway house'], Cantidad de nulos: 1
# Categoría: ['Harbor'], Cantidad de nulos: 1
# Categoría: ['Ocean'], Cantidad de nulos: 1
# Categoría: ['Transit station'], Cantidad de nulos: 1
# Categoría: ['Historical landmark'], Cantidad de nulos: 1
# Categoría: ['Rapids'], Cantidad de nulos: 1
# Categoría: ['Hiking area'], Cantidad de nulos: 1
# Categoría: ['Restaurant'], Cantidad de nulos: 1
# Categoría: ['Weather forecast service'], Cantidad de nulos: 1
# Categoría: ['Housing cooperative'], Cantidad de nulos: 1
# Categoría: ['Shopping mall'], Cantidad de nulos: 1
# Categoría: ['Community garden'], Cantidad de nulos: 1
#
# Total de filas con 'city' nulo: 667

# %%
# Exportamos metadata-sitios limpio a parquet
df_metadata_google.to_parquet("Datasets/Google/metadata-sitios/metadata-limpio.parquet")

# %%
df_metadata_google.shape
# Out:
# (933025, 11)

# %% [markdown]
# **Se unifica "review-estados" en un solo Dataframe**

# %%
# Directorio donde se encuentran tus archivos .parquet
directorio = "Datasets/Google/review-estados/review-estados-parquet"

# Listamos todos los archivos .parquet en el directorio
archivos_parquet = glob.glob(os.path.join(directorio, "*.parquet"))

# Leemos y concatenamos los archivos
df_review_estados = pd.concat([pd.read_parquet(archivo) for archivo in archivos_parquet], ignore_index=True)

# %%
df_review_estados.head(3)
# Out:
#         user_id            name           time  rating  \
# 0  1.140765e+20   Jeff Mccomish  1612059976820       5
# 1  1.015203e+20     Outlaw PiRu  1544752859553       5
# 2  1.118002e+20  Hector Acevedo  1564367962353       5
#
#                                                 text  \
# 0                  Great friendly independent packie
# 1  Great Atmosphere and Great Service. Fantastic ...
# 2  Nice neighborhood store with great sandwiches ...
#
#                                  gmap_id
# 0  0x89e64b04d274c9d9:0x84d833dcc10ae21d
# 1  0x89e64b04d274c9d9:0x84d833dcc10ae21d
# 2  0x89e64b04d274c9d9:0x84d833dcc10ae21d

# %%
df_review_estados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27158193 entries, 0 to 27158192
# Data columns (total 6 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  float64
#  1   name     object
#  2   time     int64
#  3   rating   int64
#  4   text     object
#  5   gmap_id  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.2+ GB

# %% [markdown]
# ### **Chequeo Duplicados**

# %%
# Contar el número de duplicados
num_duplicados = df_review_estados.duplicated().sum()

# Guardar el número original de filas
num_filas_original = len(df_review_estados)

# Eliminar duplicados
df_review_estados_sin_duplicados = df_review_estados.drop_duplicates()

# Calcular el número de filas después de eliminar duplicados
num_filas_final = len(df_review_estados_sin_duplicados)

# Calcular el porcentaje de reducción
porcentaje_reduccion = ((num_filas_original - num_filas_final) / num_filas_original) * 100

# Imprimir resultados
print(f"Número de duplicados eliminados: {num_duplicados}")
print(f"Tamaño original del DataFrame: {num_filas_original} filas")
print(f"Tamaño del DataFrame sin duplicados: {num_filas_final} filas")
print(f"Porcentaje de reducción: {porcentaje_reduccion:.2f}%")

# Actualizar el DataFrame original sin duplicados
df_review_estados = df_review_estados_sin_duplicados.reset_index(drop=True)
# Out:
# Número de duplicados eliminados: 491681
# Tamaño original del DataFrame: 27158193 filas
# Tamaño del DataFrame sin duplicados: 26666512 filas
# Porcentaje de reducción: 1.81%

# %% [markdown]
# ### **Se eliminan categorías no necesarias excepto "hoteles" y "restaurantes"**

# %%
df_google = pd.read_parquet('Datasets\Google\metadata-sitios\metadata-limpio.parquet')

# %%
df_google.head(3)
# Out:
#                              name  \
# 0                 Porter Pharmacy
# 14                    NTK OUTDOOR
# 45  Cruises Inc. - Connie Stewart
#
#                                               address  \
# 0   Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
#
#                                   gmap_id   latitude  longitude  \
# 0   0x88f16e41928ff687:0x883dad4fd048e8f8  32.388300 -83.357100
# 14   0x88d9beb4fe0532c1:0xef0555c169299d6  25.795204 -80.366038
# 45  0x88c2e49b79f06c31:0x4ed8c8ce27e926e0  27.832187 -82.704805
#
#               category  avg_rating  num_of_reviews estado nombre_estado  \
# 0           [Pharmacy]         4.9              16     GA       Georgia
# 14  [Corporate office]         5.0              35     FL       Florida
# 45     [Cruise agency]         5.0               2     FL       Florida
#
#              city
# 0         Cochran
# 14          Miami
# 45  Pinellas Park

# %%
df_restaurants = df_google[df_google['category'].apply(lambda x: any('restaurant' in item.lower() for item in x))]

df_restaurants
# Out:
#                                              name  \
# 114                            Cape Seafood Shack
# 115                    Fresh Point Country Buffet
# 183                    Benny's Famous Fried Clams
# 219                                 The Aynor Inn
# 250                               Paula's Kitchen
# ...                                           ...
# 3024795  Jeremy's Honduras Restaurant & Billiards
# 3024835                       Liberty Pizza & Sub
# 3024846                                      Melt
# 3024907                        China King Express
# 3024976                  House of Gourmet -- 食全食美
#
#                                                    address  \
# 114      Cape Seafood Shack, 603 Del Prado Blvd S, Cape...
# 115      Fresh Point Country Buffet, 10525 US-19, Pinel...
# 183      Benny's Famous Fried Clams, 199 W Commercial S...
# 219            The Aynor Inn, 343 8th Ave, Aynor, SC 29511
# 250      Paula's Kitchen, 777 Elmwood Ave, Providence, ...
# ...                                                    ...
# 3024795  Jeremy's Honduras Restaurant & Billiards, 581 ...
# 3024835  Liberty Pizza & Sub, 8136 Liberty Road Unit #G...
# 3024846  Melt, 6325 Windsor Mill Rd # 1, Baltimore, MD ...
# 3024907  China King Express, 6938 Erie Rd, Derby, NY 14047
# 3024976  House of Gourmet -- 食全食美, 2865 Sheridan Dr Sui...
#
#                                        gmap_id   latitude  longitude  \
# 114      0x88db4147b1d9e6f3:0x943dbd10a92ba1b1  26.641377 -81.940545
# 115      0x88c2e4e34f1ed783:0x76c5da381c499d79  27.867489 -82.702971
# 183      0x4cb29c1dea53f29f:0xc606af14a0995094  43.643365 -70.272457
# 219      0x890007d78c3e5ab9:0x4f105096aaef191d  33.996785 -79.202560
# 250      0x89e44fe1c2a2a2c3:0x5fc9f6751fb29737  41.790994 -71.422631
# ...                                        ...        ...        ...
# 3024795  0x89c3c6ecb92e945d:0x47c8160d587d3265  40.486796 -74.468884
# 3024835  0x89c81997ab131515:0xee746ac21887fe01  39.355377 -76.761759
# 3024846  0x89c81bdd8ae87749:0xd0c17064d8560660  39.321513 -76.726280
# 3024907  0x89d31f176b64da79:0x202faca0f650e880  42.698185 -78.988253
# 3024976   0x89d373386b718fff:0xf82c90ef48e7b23  42.980251 -78.827337
#
#                                                   category  avg_rating  \
# 114                                           [Restaurant]         5.0
# 115                                    [Buffet restaurant]         5.0
# 183                                           [Restaurant]         2.8
# 219      [Buffet restaurant, Family restaurant, Seafood...         4.3
# 250                                 [Dominican restaurant]         4.7
# ...                                                    ...         ...
# 3024795         [Honduran restaurant, Delivery Restaurant]         3.8
# 3024835                                       [Restaurant]         3.0
# 3024846                                 [Pizza restaurant]         4.2
# 3024907                               [Chinese restaurant]         4.1
# 3024976           [Chinese restaurant, Sichuan restaurant]         4.3
#
#          num_of_reviews estado   nombre_estado           city
# 114                   1     FL         Florida     Cape Coral
# 115                   2     FL         Florida  Pinellas Park
# 183                  17     ME           Maine       Portland
# 219                   2     SC  South Carolina          Aynor
# 250                  18     RI    Rhode Island     Providence
# ...                 ...    ...             ...            ...
# 3024795             118     NJ      New Jersey       Somerset
# 3024835             108     MD        Maryland   Windsor Mill
# 3024846             108     MD        Maryland      Baltimore
# 3024907             118     NY        New York          Derby
# 3024976              58     NY        New York      Tonawanda
#
# [73892 rows x 11 columns]

# %% [markdown]
# ### **EDA Análisis Exploratorio de Datos - Google**

# %% [markdown]
# Se filtra el dataframe por categorías de Restaurantes y Hoteles

# %%
import ast 
#Convertimos las cadenas a listas (si los datos son cadenas que parecen listas)
df_google['category'] = df_google['category'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) and x.startswith('[') else x)

# Usamos "explode" en la columna "category" para separar las listas en filas individuales
df_exploded = df_google.explode('category')

#Filtramos las filas por palabras clave
keywords = r'(?:\s|^)(Restaurant|Restaurants|Hotel|Hotels|Tourism)(?:\s|$)'
df_restaurants_hotels = df_exploded[df_exploded['category'].str.contains(keywords, case=False, na=False, regex=True)]

#Mostramos el DataFrame filtrado
df_restaurants_hotels
# Out:
# C:\Users\54370\AppData\Local\Temp\ipykernel_2228\2198727474.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_restaurants_hotels = df_exploded[df_exploded['category'].str.contains(keywords, case=False, na=False, regex=True)]
#                                name  \
# 114              Cape Seafood Shack
# 115      Fresh Point Country Buffet
# 183      Benny's Famous Fried Clams
# 219                   The Aynor Inn
# 219                   The Aynor Inn
# ...                             ...
# 3024835         Liberty Pizza & Sub
# 3024846                        Melt
# 3024907          China King Express
# 3024976    House of Gourmet -- 食全食美
# 3024976    House of Gourmet -- 食全食美
#
#                                                    address  \
# 114      Cape Seafood Shack, 603 Del Prado Blvd S, Cape...
# 115      Fresh Point Country Buffet, 10525 US-19, Pinel...
# 183      Benny's Famous Fried Clams, 199 W Commercial S...
# 219            The Aynor Inn, 343 8th Ave, Aynor, SC 29511
# 219            The Aynor Inn, 343 8th Ave, Aynor, SC 29511
# ...                                                    ...
# 3024835  Liberty Pizza & Sub, 8136 Liberty Road Unit #G...
# 3024846  Melt, 6325 Windsor Mill Rd # 1, Baltimore, MD ...
# 3024907  China King Express, 6938 Erie Rd, Derby, NY 14047
# 3024976  House of Gourmet -- 食全食美, 2865 Sheridan Dr Sui...
# 3024976  House of Gourmet -- 食全食美, 2865 Sheridan Dr Sui...
#
#                                        gmap_id   latitude  longitude  \
# 114      0x88db4147b1d9e6f3:0x943dbd10a92ba1b1  26.641377 -81.940545
# 115      0x88c2e4e34f1ed783:0x76c5da381c499d79  27.867489 -82.702971
# 183      0x4cb29c1dea53f29f:0xc606af14a0995094  43.643365 -70.272457
# 219      0x890007d78c3e5ab9:0x4f105096aaef191d  33.996785 -79.202560
# 219      0x890007d78c3e5ab9:0x4f105096aaef191d  33.996785 -79.202560
# ...                                        ...        ...        ...
# 3024835  0x89c81997ab131515:0xee746ac21887fe01  39.355377 -76.761759
# 3024846  0x89c81bdd8ae87749:0xd0c17064d8560660  39.321513 -76.726280
# 3024907  0x89d31f176b64da79:0x202faca0f650e880  42.698185 -78.988253
# 3024976   0x89d373386b718fff:0xf82c90ef48e7b23  42.980251 -78.827337
# 3024976   0x89d373386b718fff:0xf82c90ef48e7b23  42.980251 -78.827337
#
#                    category  avg_rating  num_of_reviews estado  \
# 114              Restaurant         5.0               1     FL
# 115       Buffet restaurant         5.0               2     FL
# 183              Restaurant         2.8              17     ME
# 219       Buffet restaurant         4.3               2     SC
# 219       Family restaurant         4.3               2     SC
# ...                     ...         ...             ...    ...
# 3024835          Restaurant         3.0             108     MD
# 3024846    Pizza restaurant         4.2             108     MD
# 3024907  Chinese restaurant         4.1             118     NY
# 3024976  Chinese restaurant         4.3              58     NY
# 3024976  Sichuan restaurant         4.3              58     NY
#
#           nombre_estado           city
# 114             Florida     Cape Coral
# 115             Florida  Pinellas Park
# 183               Maine       Portland
# 219      South Carolina          Aynor
# 219      South Carolina          Aynor
# ...                 ...            ...
# 3024835        Maryland   Windsor Mill
# 3024846        Maryland      Baltimore
# 3024907        New York          Derby
# 3024976        New York      Tonawanda
# 3024976        New York      Tonawanda
#
# [136072 rows x 11 columns]

# %% [markdown]
# ### **Filtrado por Restaurantes chinos**

# %%
import ast 

# Filtramos las filas por palabras clave
keywords = r'(?:\s|^)(Chinese restaurant|Delivery Chinese restaurant|Chinese noodle restaurant)(?:\s|$)'
df_cr = df_restaurants_hotels[df_restaurants_hotels['category'].str.contains(keywords, case=False, na=False, regex=True)]

#Mostramos el DataFrame filtrado
df_cr
# Out:
# C:\Users\54370\AppData\Local\Temp\ipykernel_2228\1087630366.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_cr = df_restaurants_hotels[df_restaurants_hotels['category'].str.contains(keywords, case=False, na=False, regex=True)]
#                                              name  \
# 2880          China House Chinese & American Food
# 8172                                         WUJI
# 8820                                Panda Express
# 9238                     Good Taste Asian Cuisine
# 9428                                  Wok 'n Roll
# ...                                           ...
# 3024124                                 China One
# 3024281                     Lucky Chinese Kitchen
# 3024636  Fu Zhou Wei Zhong Wei Jia Xiang Feng Wei
# 3024907                        China King Express
# 3024976                  House of Gourmet -- 食全食美
#
#                                                    address  \
# 2880     China House Chinese & American Food, 827 Broad...
# 8172            WUJI, 68 E Putnam Ave, Greenwich, CT 06830
# 8820     Panda Express, 13059 Lee Jackson Memorial Hwy,...
# 9238     Good Taste Asian Cuisine, 42 Central St, Ipswi...
# 9428      Wok 'n Roll, 1101 Bunn Hill Rd, Vestal, NY 13850
# ...                                                    ...
# 3024124  China One, 2003, 4019 Cedar Ln, Portsmouth, VA...
# 3024281  Lucky Chinese Kitchen, 970 18th Ave, Newark, N...
# 3024636  Fu Zhou Wei Zhong Wei Jia Xiang Feng Wei, 88 E...
# 3024907  China King Express, 6938 Erie Rd, Derby, NY 14047
# 3024976  House of Gourmet -- 食全食美, 2865 Sheridan Dr Sui...
#
#                                        gmap_id   latitude  longitude  \
# 2880     0x89c6c8e87f60800d:0xbacca2e5a90bdfcb  39.935655 -75.119530
# 8172     0x89c29846a70925f3:0xd15fd18f2efe0a63  41.032745 -73.624310
# 8820     0x89b645175b2f5bf1:0x4000b96ee41f94d9  38.880261 -77.398403
# 9238     0x89e318c6e45de21f:0xb3073257db94786c  42.680840 -70.839105
# 9428     0x89daeebc3aa5c9f9:0x351fcdc697f3dded  42.094293 -75.975989
# ...                                        ...        ...        ...
# 3024124  0x89ba9f3a2c094059:0xc56405cc884fd2ef  36.877227 -76.377279
# 3024281  0x89c3acb040ae9dd9:0x9ed1ab06d415b98c  40.739035 -74.227925
# 3024636  0x89c25a289b0b70ab:0xad50a4eff25976fc  40.713835 -73.994140
# 3024907  0x89d31f176b64da79:0x202faca0f650e880  42.698185 -78.988253
# 3024976   0x89d373386b718fff:0xf82c90ef48e7b23  42.980251 -78.827337
#
#                             category  avg_rating  num_of_reviews estado  \
# 2880              Chinese restaurant         5.0               4     NJ
# 8172              Chinese restaurant         3.8              18     CT
# 8820              Chinese restaurant         3.8              48     VA
# 9238              Chinese restaurant         4.1              68     MA
# 9428              Chinese restaurant         4.0              18     NY
# ...                              ...         ...             ...    ...
# 3024124  Delivery Chinese restaurant         4.3              48     VA
# 3024281           Chinese restaurant         3.5              28     NJ
# 3024636           Chinese restaurant         4.6               8     NY
# 3024907           Chinese restaurant         4.1             118     NY
# 3024976           Chinese restaurant         4.3              58     NY
#
#          nombre_estado        city
# 2880        New Jersey      Camden
# 8172       Connecticut   Greenwich
# 8820          Virginia     Fairfax
# 9238     Massachusetts     Ipswich
# 9428          New York      Vestal
# ...                ...         ...
# 3024124       Virginia  Portsmouth
# 3024281     New Jersey      Newark
# 3024636       New York    New York
# 3024907       New York       Derby
# 3024976       New York   Tonawanda
#
# [5452 rows x 11 columns]

# %% [markdown]
# ### **Comparación del mercado de comida china, restaurantes con mayor cantidad de locales**

# %%
# Contamos la cantidad de locales de cada restaurante según el nombre
restaurant_counts = df_cr['name'].value_counts()

# Obtenemos el top 10 de restaurantes con más locales
top_10_restaurants = restaurant_counts.head(10)

# Visualizamos los resultados
plt.figure(figsize=(12, 6))

# Creamos el gráfico de barras con Seaborn
ax = sns.barplot(x=top_10_restaurants.values, y=top_10_restaurants.index, palette='coolwarm')

# Añadimos etiquetas y título
plt.title('Top 10 Restaurantes con Más Locales')
plt.xlabel('Número de Locales')
plt.ylabel('Nombre del Restaurante')

# Añadimos anotaciones de las cantidades en cada barra
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', 
                (p.get_width() + 0.1, p.get_y() + p.get_height() / 2), 
                ha='center', 
                va='center', 
                fontsize=10, 
                color='black')
 
# Mostramos el gráfico
plt.show()
# Out:
# C:\Users\54370\AppData\Local\Temp\ipykernel_2228\3053167391.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_10_restaurants.values, y=top_10_restaurants.index, palette='coolwarm')

# %% [markdown]
# ### **Top 20 de los restaurantes con más locales de comida China con mejor calificación promedio**

# %%
# Contamos la cantidad de locales de cada restaurante según el nombre
restaurant_counts = df_cr['name'].value_counts()

# Obtenemos el top 10 de restaurantes con más locales
top_10_restaurants = restaurant_counts.head(20).index

# Filtramos el DataFrame original para incluir solo estos restaurantes
filtered_df = df_cr[df_cr['name'].isin(top_10_restaurants)]

# Calculamos la calificación promedio para cada restaurante en el top 10
avg_ratings = filtered_df.groupby('name')['avg_rating'].mean()

# Ordenamos los restaurantes por calificación promedio y seleccionar el top 10
top_10_avg_ratings = avg_ratings.sort_values(ascending=False).head(20)

# Visualizamos los resultados
plt.figure(figsize=(12, 6))

# Creamos el gráfico de barras con Seaborn
ax = sns.barplot(x=top_10_avg_ratings.values, y=top_10_avg_ratings.index, palette='coolwarm')

# Añadimos etiquetas y título
plt.title('Top 20 Restaurantes con Mejor Calificación Promedio entre los que Tienen Más Locales')
plt.xlabel('Calificación Promedio')
plt.ylabel('Nombre del Restaurante')

# Añadimos anotaciones de las calificaciones en cada barra
for p in ax.patches:
    ax.annotate(f'{p.get_width():.2f}', 
                (p.get_width() + 0.05, p.get_y() + p.get_height() / 2), 
                ha='center', 
                va='center', 
                fontsize=10, 
                color='black')

# Mostramos el gráfico
plt.show()
# Out:
# C:\Users\54370\AppData\Local\Temp\ipykernel_2228\1660014853.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_10_avg_ratings.values, y=top_10_avg_ratings.index, palette='coolwarm')

# %% [markdown]
# ### **Top 10 restaurantes con más reseñas entre los que tienen más locales**

# %%
# Contamos la cantidad de locales de cada restaurante según el nombre
restaurant_counts = df_cr['name'].value_counts()

# Obtenemos el top 10 de restaurantes con más locales
top_10_restaurants = restaurant_counts.head(10).index

# Filtramos el DataFrame original para incluir solo estos restaurantes
filtered_df = df_cr[df_cr['name'].isin(top_10_restaurants)]

# Contamos el número total de reseñas para cada restaurante en el top 10
total_reviews = filtered_df.groupby('name')['num_of_reviews'].sum()

# Ordenamos los restaurantes por número total de reseñas y seleccionamos el top 10
top_10_reviews = total_reviews.sort_values(ascending=False).head(10)

# Visualizamos los resultados
plt.figure(figsize=(12, 6))

# Creamos el gráfico de barras con Seaborn
ax = sns.barplot(x=top_10_reviews.values, y=top_10_reviews.index, palette='coolwarm')

# Añadimos etiquetas y título
plt.title('Top 10 Restaurantes con Más Reseñas entre los que Tienen Más Locales')
plt.xlabel('Número Total de Reseñas')
plt.ylabel('Nombre del Restaurante')

# Añadimos anotaciones de las reseñas en cada barra
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', 
                (p.get_width() + 0.05, p.get_y() + p.get_height() / 2), 
                ha='center', 
                va='center', 
                fontsize=10, 
                color='black')

# Mostramos el gráfico
plt.show()
# Out:
# C:\Users\54370\AppData\Local\Temp\ipykernel_2228\2522842077.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_10_reviews.values, y=top_10_reviews.index, palette='coolwarm')

# %% [markdown]
# ### **Análisis específico de la cadena China Garden**

# %%
df_metadata_google = pd.read_parquet('Datasets\Google\metadata-sitios\metadata-limpio.parquet')
df_metadata_google.head(3)
# Out:
#                              name  \
# 0                 Porter Pharmacy
# 14                    NTK OUTDOOR
# 45  Cruises Inc. - Connie Stewart
#
#                                               address  \
# 0   Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 14  NTK OUTDOOR, 2315 NW 107th Ave #1B18, Miami, F...
# 45  Cruises Inc. - Connie Stewart, 6602 52nd Ln, P...
#
#                                   gmap_id   latitude  longitude  \
# 0   0x88f16e41928ff687:0x883dad4fd048e8f8  32.388300 -83.357100
# 14   0x88d9beb4fe0532c1:0xef0555c169299d6  25.795204 -80.366038
# 45  0x88c2e49b79f06c31:0x4ed8c8ce27e926e0  27.832187 -82.704805
#
#               category  avg_rating  num_of_reviews estado nombre_estado  \
# 0           [Pharmacy]         4.9              16     GA       Georgia
# 14  [Corporate office]         5.0              35     FL       Florida
# 45     [Cruise agency]         5.0               2     FL       Florida
#
#              city
# 0         Cochran
# 14          Miami
# 45  Pinellas Park

# %%
# Filtramos los restaurantes 'China Garden'
china_garden_df = df_metadata_google[df_metadata_google['name'] == 'China Garden']

# Contamos el número de locales
num_locales = len(china_garden_df)

# Calculamos el promedio de 'avg_rating'
avg_rating_total = china_garden_df['avg_rating'].mean()

print(f"Número de locales de China Garden: {num_locales}")
print(f"Puntuación promedio (avg_rating) de China Garden: {avg_rating_total:.2f}")

# Mostramos los primeros registros para verificación
print("\nPrimeros registros de China Garden:")
print(china_garden_df[['name', 'address', 'avg_rating', 'estado']].head())
# Out:
# Número de locales de China Garden: 46
# Puntuación promedio (avg_rating) de China Garden: 3.96
#
# Primeros registros de China Garden:
#                 name                                            address  \
# 121158  China Garden    China Garden, 1123 Spring Ln, Sanford, NC 27330
# 172181  China Garden    China Garden, 209 North Ave, Dunellen, NJ 08812
# 276732  China Garden  China Garden, 108 W Main St STE D, Jamestown, ...
# 277973  China Garden  China Garden, 3300 N Roosevelt Blvd 5618 296, ...
# 321981  China Garden  China Garden, 111 W Church St, Troutman, NC 28166
#
#         avg_rating estado
# 121158         4.5     NC
# 172181         3.7     NJ
# 276732         4.2     NC
# 277973         3.9     FL
# 321981         4.2     NC

# %%
china_garden_df[['name', 'avg_rating', 'city', 'nombre_estado', 'num_of_reviews']].sort_values(by='num_of_reviews', ascending=False)
# Out:
#                  name  avg_rating               city   nombre_estado  \
# 277973   China Garden         3.9           Key West         Florida
# 2471858  China Garden         4.1      Milledgeville         Georgia
# 590192   China Garden         3.6            Cameron  North Carolina
# 2118991  China Garden         3.7          Jefferson         Georgia
# 2540701  China Garden         4.1           Lakeland         Florida
# 666593   China Garden         4.0      Central Islip        New York
# 2494470  China Garden         4.3            Emporia        Virginia
# 813407   China Garden         3.8       Big Pine Key         Florida
# 731312   China Garden         4.4        Spring Hill         Florida
# 2875688  China Garden         4.4          Braselton         Georgia
# 455518   China Garden         3.8       Windsor Mill        Maryland
# 2690503  China Garden         3.6            Ansonia     Connecticut
# 755274   China Garden         3.8         Livingston      New Jersey
# 2564209  China Garden         4.2           Dayville     Connecticut
# 321981   China Garden         4.2           Troutman  North Carolina
# 495116   China Garden         3.9         Winchester        Virginia
# 2976967  China Garden         4.2          Riverside      New Jersey
# 2456303  China Garden         3.5         Loganville         Georgia
# 1397549  China Garden         4.1     Winter Springs         Florida
# 2449345  China Garden         4.3          Canastota        New York
# 579692   China Garden         4.2           Hartford     Connecticut
# 783711   China Garden         4.3           Scituate    Rhode Island
# 2956244  China Garden         4.4           Brooklyn        New York
# 654555   China Garden         4.0       Hackettstown      New Jersey
# 636570   China Garden         4.1          Hauppauge        New York
# 1805492  China Garden         4.4          Lumberton  North Carolina
# 2270284  China Garden         3.3       White Plains        New York
# 2900047  China Garden         4.4         Burlington     Connecticut
# 2294085  China Garden         3.8         Alexandria        Virginia
# 2456254  China Garden         3.6       Jacksonville         Florida
# 2934538  China Garden         3.6        Southampton        New York
# 1196389  China Garden         3.2          Cleveland  North Carolina
# 3019065  China Garden         3.7          Baltimore        Maryland
# 2551967  China Garden         3.4           Brooklyn        New York
# 1825145  China Garden         4.2      Little Silver      New Jersey
# 2726582  China Garden         3.1           Brooklyn        New York
# 172181   China Garden         3.7           Dunellen      New Jersey
# 2487432  China Garden         3.8            Mahopac        New York
# 381922   China Garden         3.8         River Edge      New Jersey
# 276732   China Garden         4.2          Jamestown  North Carolina
# 1089362  China Garden         4.4         Dolgeville        New York
# 1222947  China Garden         4.4            Trenton      New Jersey
# 2596556  China Garden         4.1     City of Orange      New Jersey
# 1258595  China Garden         3.3             Camden      New Jersey
# 121158   China Garden         4.5            Sanford  North Carolina
# 1352177  China Garden         4.3  Panama City Beach         Florida
#
#          num_of_reviews
# 277973              254
# 2471858             208
# 590192              195
# 2118991             177
# 2540701             146
# 666593              138
# 2494470             128
# 813407              127
# 731312              118
# 2875688             116
# 455518              108
# 2690503             108
# 755274               96
# 2564209              96
# 321981               87
# 495116               83
# 2976967              78
# 2456303              78
# 1397549              78
# 2449345              78
# 579692               78
# 783711               78
# 2956244              78
# 654555               74
# 636570               74
# 1805492              73
# 2270284              68
# 2900047              58
# 2294085              58
# 2456254              56
# 2934538              48
# 1196389              48
# 3019065              44
# 2551967              38
# 1825145              35
# 2726582              34
# 172181               34
# 2487432              33
# 381922               29
# 276732               28
# 1089362              28
# 1222947              28
# 2596556              26
# 1258595               8
# 121158                6
# 1352177               4

# %%
# Filtramos los restaurantes 'China Garden'
china_garden_df = df_metadata_google[df_metadata_google['name'] == 'China Garden']

# Agrupamos por ciudad y contar el número de restaurantes
city_distribution = china_garden_df.groupby('city').size().sort_values(ascending=False).reset_index(name='count')

# Calculamos el rating promedio por ciudad
city_avg_rating = china_garden_df.groupby('city')['avg_rating'].mean().round(2)

# Combinamos el conteo y el rating promedio
city_analysis = city_distribution.merge(city_avg_rating, on='city', how='left')

# Renombramos las columnas para mayor claridad
city_analysis.columns = ['Ciudad', 'Número de Restaurantes', 'Rating Promedio']

# Mostramos los resultados
print("Distribución de restaurantes China Garden por ciudad:")
print(city_analysis.to_string(index=False))

# Calculamos y mostramos estadísticas generales
total_restaurants = city_analysis['Número de Restaurantes'].sum()
total_cities = len(city_analysis)
overall_avg_rating = china_garden_df['avg_rating'].mean()

print(f"\nEstadísticas Generales:")
print(f"Total de restaurantes China Garden: {total_restaurants}")
print(f"Número de ciudades con presencia: {total_cities}")
print(f"Rating promedio general: {overall_avg_rating:.2f}")
# Out:
# Distribución de restaurantes China Garden por ciudad:
#            Ciudad  Número de Restaurantes  Rating Promedio
#          Brooklyn                       3             3.63
#        Alexandria                       1             3.80
#         Baltimore                       1             3.70
#           Ansonia                       1             3.60
#      Big Pine Key                       1             3.80
#         Braselton                       1             4.40
#        Burlington                       1             4.40
#            Camden                       1             3.30
#           Cameron                       1             3.60
#         Canastota                       1             4.30
#     Central Islip                       1             4.00
#    City of Orange                       1             4.10
#         Cleveland                       1             3.20
#          Dayville                       1             4.20
#        Dolgeville                       1             4.40
#          Dunellen                       1             3.70
#           Emporia                       1             4.30
#      Hackettstown                       1             4.00
#          Hartford                       1             4.20
#         Hauppauge                       1             4.10
#      Jacksonville                       1             3.60
#         Jamestown                       1             4.20
#         Jefferson                       1             3.70
#          Key West                       1             3.90
#          Lakeland                       1             4.10
#     Little Silver                       1             4.20
#        Livingston                       1             3.80
#        Loganville                       1             3.50
#         Lumberton                       1             4.40
#           Mahopac                       1             3.80
#     Milledgeville                       1             4.10
# Panama City Beach                       1             4.30
#        River Edge                       1             3.80
#         Riverside                       1             4.20
#           Sanford                       1             4.50
#          Scituate                       1             4.30
#       Southampton                       1             3.60
#       Spring Hill                       1             4.40
#           Trenton                       1             4.40
#          Troutman                       1             4.20
#      White Plains                       1             3.30
#        Winchester                       1             3.90
#      Windsor Mill                       1             3.80
#    Winter Springs                       1             4.10
#
# Estadísticas Generales:
# Total de restaurantes China Garden: 46
# Número de ciudades con presencia: 44
# Rating promedio general: 3.96

# %%
# Ordenamos los datos por número de restaurantes y tomar las top 10 ciudades
top_10_cities = city_analysis.sort_values('Número de Restaurantes', ascending=False).head(10)

# Creamos el gráfico de barras
plt.figure(figsize=(12, 6))
bars = plt.bar(top_10_cities['Ciudad'], top_10_cities['Número de Restaurantes'])

# Personalizamos el gráfico
plt.title('Top 10 Ciudades con Más Restaurantes China Garden', fontsize=16)
plt.xlabel('Ciudad', fontsize=12)
plt.ylabel('Número de Restaurantes', fontsize=12)
plt.xticks(rotation=45, ha='right')

# Añadimos etiquetas de valor encima de cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height}',
             ha='center', va='bottom')

# Añadimos el rating promedio como texto en cada barra
for i, bar in enumerate(bars):
    rating = top_10_cities.iloc[i]['Rating Promedio']
    plt.text(bar.get_x() + bar.get_width()/2., bar.get_height()/2,
             f'Rating: {rating}',
             ha='center', va='center', rotation=90, color='white', fontweight='bold')

plt.tight_layout()
plt.show()

# %%
china_garden_df['nombre_estado'].value_counts()
# Out:
# nombre_estado
# New York          10
# New Jersey         9
# Florida            7
# North Carolina     6
# Connecticut        4
# Georgia            4
# Virginia           3
# Maryland           2
# Rhode Island       1
# Name: count, dtype: int64

# %% [markdown]
# ### **Ubicación de los locales de China Garden**

# %%
# %pip install folium
# Out:
# Requirement already satisfied: folium in d:\proyecto final\venv\lib\site-packages (0.17.0)
# Requirement already satisfied: branca>=0.6.0 in d:\proyecto final\venv\lib\site-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in d:\proyecto final\venv\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in d:\proyecto final\venv\lib\site-packages (from folium) (2.1.0)
# Requirement already satisfied: requests in d:\proyecto final\venv\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in d:\proyecto final\venv\lib\site-packages (from folium) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\proyecto final\venv\lib\site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\proyecto final\venv\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\proyecto final\venv\lib\site-packages (from requests->folium) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\proyecto final\venv\lib\site-packages (from requests->folium) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\proyecto final\venv\lib\site-packages (from requests->folium) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# Creamos un mapa centrado en el punto promedio de todas las ubicaciones
map_center = [china_garden_df['latitude'].mean(), china_garden_df['longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=14)

# Añadimos marcadores para cada local
for _, row in china_garden_df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['name'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)

# Guardamos el mapa en un archivo HTML
m.save('china_garden_map.html')

# Para visualizar en Jupyter Notebook, descomentar la siguiente línea
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_018f77f39408eae38a9973351968430b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_018f77f39408eae38a9973351968430b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_018f77f39408eae38a9973351968430b = L.map(
#                 &quot;map_018f77f39408eae38a9973351968430b&quot;,
#                 {
#                     center: [37.43965045434782, -77.11565281521739],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a7f02ff858d0f2d0a528eeed258809ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a7f02ff858d0f2d0a528eeed258809ca.addTo(map_018f77f39408eae38a9973351968430b);
#
#
#             var marker_0fee7356a1997a153806d70e4e943f5e = L.marker(
#                 [35.4864536, -79.2017692],
#                 {}
#             ).addTo(map_018f77f39408eae38a9973351968430b);
#
#
#             var icon_03655970ee95614edb3352995f0ae0c5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0fee7356a1997a153806d70e4e943f5e.setIcon(icon_03655970ee95614edb3352995f0ae0c5);
#
#
#         var popup_960329d374802721da1b3883be28f4b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a2f733dfb3b0c79924e24ee1d95f5ad = $(`&lt;div id=&quot;html_9a2f733dfb3b0c79924e24ee1d95f5ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;China Garden&lt;/div&gt;`)[0];
#                 popup_960329d374802721da1b3883be28f4b4.setContent(html_9a2f733dfb3b0c79924e24ee1d95f5ad);
#
#
#
#         marker_0fee7356a1997a153806d70e4e943f5e.bindPopup(popup_960329d374802721da1b3883be28f4b4)
#         ;
#
#
#
#
#             var marker_3fd25c0e276d4bbbba6b3dd5c86e5912 = L.marker(
#                 [40.5926359, -74.46168089999999],
#                 {}
#             ).addTo(map_018f77f39408eae38a9973351968430b);
#
#
#             var icon_386103528be8a5cf1d167f6ce99a0600 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3fd25c0e276d4bbbba6b3dd5c86e5912.setIcon(icon_386103528be8a5cf1d167f6ce99a0600);
#
#
#         var popup_e7591c3df2de4f3a13fbac496caf42f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26628ac8b6d79216cb41eea48e0e04fa = $(`&lt;div id=&quot;html_26628ac8b6d79216cb41eea48e0e04fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;China Garden&lt;/div&gt;`)[0];
#                 popup_e7591c3df2de4f3a13fbac496caf42f6.setContent(html_26628ac8b6d79216cb41eea48e0e04fa);
#
#
#
#         marker_3fd25c0e276d4bbbba6b3dd5c86e5912.bindPopup(popup_e7591c3df2de4f3a13fbac496caf42f6)
#         ;
#
#
#
#
#             var marker_3b81dae9f5b3da175eeef4b9cb4672ef = L.marker(
#                 [35.9941143, -79.9368386],
#                 {}
#             ).addTo(map_018f77f39408eae38a9973351968430b);
#
#
#             var icon_ea071637a06420c97a1c3229026dca83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3b81dae9f5b3da175eeef4b9cb4672ef.setIcon(icon_ea071637a06420c97a1c3229026dca83);
#
#
#         var popup_a0f64bf0b3c8f285b043448e8e7719bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_88c47af14b03140c61253155fc902192 = $(`&lt;div id=&quot;html_88c47af14b03140c61253155fc902192&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;China Garden&lt;/div&gt;`)[0];
#                 popup_a0f64bf0b3c8f285b043448e8e7719bf.setContent(html_88c47af14b03140c61253155fc902192);
#
#
#
#         marker_3b81dae9f5b3da175eeef4b9cb4672ef.bindPopup(popup_a0f64bf0b3c8f285b043448e8e7719bf)
#         ;
#
#
#
#
#             var marker_217f73242dfd6e48db50b016b791a366 = L.marker(
#                 [24.569116599999997, -81.76447759999999],
#                 {}
#             ).addTo(map_018f77f39408eae38a9973351968430b);
#
#
#             var icon_4758ce2705f11fb3b09972bdf4493723 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;

# %%
china_garden_df.head(3)
# Out:
#                 name                                            address  \
# 121158  China Garden    China Garden, 1123 Spring Ln, Sanford, NC 27330
# 172181  China Garden    China Garden, 209 North Ave, Dunellen, NJ 08812
# 276732  China Garden  China Garden, 108 W Main St STE D, Jamestown, ...
#
#                                       gmap_id   latitude  longitude  \
# 121158  0x89aca89dadfa8ed9:0xf8464b9a9871c040  35.486454 -79.201769
# 172181  0x89c3b9050ecda13d:0xe7d0cc1f0b785345  40.592636 -74.461681
# 276732  0x88530fea3a837eef:0xb20c7dce9609954c  35.994114 -79.936839
#
#                                                  category  avg_rating  \
# 121158                                       [Restaurant]         4.5
# 172181  [Chinese restaurant, Asian restaurant, Deliver...         3.7
# 276732                               [Chinese restaurant]         4.2
#
#         num_of_reviews estado   nombre_estado       city
# 121158               6     NC  North Carolina    Sanford
# 172181              34     NJ      New Jersey   Dunellen
# 276732              28     NC  North Carolina  Jamestown

# %%
df_review_estados.head(3)
# Out:
#         user_id            name           time  rating  \
# 0  1.140765e+20   Jeff Mccomish  1612059976820       5
# 1  1.015203e+20     Outlaw PiRu  1544752859553       5
# 2  1.118002e+20  Hector Acevedo  1564367962353       5
#
#                                                 text  \
# 0                  Great friendly independent packie
# 1  Great Atmosphere and Great Service. Fantastic ...
# 2  Nice neighborhood store with great sandwiches ...
#
#                                  gmap_id
# 0  0x89e64b04d274c9d9:0x84d833dcc10ae21d
# 1  0x89e64b04d274c9d9:0x84d833dcc10ae21d
# 2  0x89e64b04d274c9d9:0x84d833dcc10ae21d

# %% [markdown]
# ### **Unión DataFrame "china garden" con "review-estados"**

# %%
df_china_garden_reviews = pd.merge(china_garden_df, df_review_estados, on='gmap_id', how='inner')  # inner, left, right, outer

print(df_china_garden_reviews)
# Out:
#             name_x                                            address  \
# 0     China Garden    China Garden, 209 North Ave, Dunellen, NJ 08812
# 1     China Garden    China Garden, 209 North Ave, Dunellen, NJ 08812
# 2     China Garden    China Garden, 209 North Ave, Dunellen, NJ 08812
# 3     China Garden    China Garden, 209 North Ave, Dunellen, NJ 08812
# 4     China Garden    China Garden, 209 North Ave, Dunellen, NJ 08812
# ...            ...                                                ...
# 1652  China Garden  China Garden, 8653 Belair Rd, Baltimore, MD 21236
# 1653  China Garden  China Garden, 8653 Belair Rd, Baltimore, MD 21236
# 1654  China Garden  China Garden, 8653 Belair Rd, Baltimore, MD 21236
# 1655  China Garden  China Garden, 8653 Belair Rd, Baltimore, MD 21236
# 1656  China Garden  China Garden, 8653 Belair Rd, Baltimore, MD 21236
#
#                                     gmap_id   latitude  longitude  \
# 0     0x89c3b9050ecda13d:0xe7d0cc1f0b785345  40.592636 -74.461681
# 1     0x89c3b9050ecda13d:0xe7d0cc1f0b785345  40.592636 -74.461681
# 2     0x89c3b9050ecda13d:0xe7d0cc1f0b785345  40.592636 -74.461681
# 3     0x89c3b9050ecda13d:0xe7d0cc1f0b785345  40.592636 -74.461681
# 4     0x89c3b9050ecda13d:0xe7d0cc1f0b785345  40.592636 -74.461681
# ...                                     ...        ...        ...
# 1652  0x89c8084dc314f81d:0xce874e29ca76327d  39.390398 -76.488866
# 1653  0x89c8084dc314f81d:0xce874e29ca76327d  39.390398 -76.488866
# 1654  0x89c8084dc314f81d:0xce874e29ca76327d  39.390398 -76.488866
# 1655  0x89c8084dc314f81d:0xce874e29ca76327d  39.390398 -76.488866
# 1656  0x89c8084dc314f81d:0xce874e29ca76327d  39.390398 -76.488866
#
#                                                category  avg_rating  \
# 0     [Chinese restaurant, Asian restaurant, Deliver...         3.7
# 1     [Chinese restaurant, Asian restaurant, Deliver...         3.7
# 2     [Chinese restaurant, Asian restaurant, Deliver...         3.7
# 3     [Chinese restaurant, Asian restaurant, Deliver...         3.7
# 4     [Chinese restaurant, Asian restaurant, Deliver...         3.7
# ...                                                 ...         ...
# 1652  [Chinese restaurant, Asian fusion restaurant, ...         3.7
# 1653  [Chinese restaurant, Asian fusion restaurant, ...         3.7
# 1654  [Chinese restaurant, Asian fusion restaurant, ...         3.7
# 1655  [Chinese restaurant, Asian fusion restaurant, ...         3.7
# 1656  [Chinese restaurant, Asian fusion restaurant, ...         3.7
#
#       num_of_reviews estado nombre_estado       city       user_id  \
# 0                 34     NJ    New Jersey   Dunellen  1.125038e+20
# 1                 34     NJ    New Jersey   Dunellen  1.076216e+20
# 2                 34     NJ    New Jersey   Dunellen  1.142247e+20
# 3                 34     NJ    New Jersey   Dunellen  1.169691e+20
# 4                 34     NJ    New Jersey   Dunellen  1.063769e+20
# ...              ...    ...           ...        ...           ...
# 1652              44     MD      Maryland  Baltimore  1.126571e+20
# 1653              44     MD      Maryland  Baltimore  1.141836e+20
# 1654              44     MD      Maryland  Baltimore  1.096521e+20
# 1655              44     MD      Maryland  Baltimore  1.171411e+20
# 1656              44     MD      Maryland  Baltimore  1.099213e+20
#
#                                    name_y           time  rating  \
# 0                           John Campbell  1544466023862       4
# 1                           Cheryl Kimble  1483899014865       5
# 2                          Spencer Duncan  1468894704924       4
# 3                           Keri Oleniach  1497268187603       5
# 4                       Unmasked Sidekick  1442353315596       1
# ...                                   ...            ...     ...
# 1652                                Sc1re  1473443822908       5
# 1653                          Chuck Abuck  1579869643835       4
# 1654                  Elizabeth Hendricks  1506735566379       3
# 1655                            Kim Myers  1567977388665       5
# 1656  Ferran Santiago Garcia Del Castillo  1544123196307       5
#
#                                                    text
# 0                                 Good food good prices
# 1       The food is good and they are quick to prepare.
# 2     bizarre place but the food was pretty good act...
# 3     Favorite Chinese takeout in area. Great food a...
# 4     Ordered delivery get old soda and no fork or s...
# ...                                                 ...
# 1652                                               None
# 1653                                               None
# 1654                                               None
# 1655                                               None
# 1656                                               None
#
# [1657 rows x 16 columns]

# %%
df_china_garden_reviews.head(3)
# Out:
#          name_x                                          address  \
# 0  China Garden  China Garden, 209 North Ave, Dunellen, NJ 08812
# 1  China Garden  China Garden, 209 North Ave, Dunellen, NJ 08812
# 2  China Garden  China Garden, 209 North Ave, Dunellen, NJ 08812
#
#                                  gmap_id   latitude  longitude  \
# 0  0x89c3b9050ecda13d:0xe7d0cc1f0b785345  40.592636 -74.461681
# 1  0x89c3b9050ecda13d:0xe7d0cc1f0b785345  40.592636 -74.461681
# 2  0x89c3b9050ecda13d:0xe7d0cc1f0b785345  40.592636 -74.461681
#
#                                             category  avg_rating  \
# 0  [Chinese restaurant, Asian restaurant, Deliver...         3.7
# 1  [Chinese restaurant, Asian restaurant, Deliver...         3.7
# 2  [Chinese restaurant, Asian restaurant, Deliver...         3.7
#
#    num_of_reviews estado nombre_estado      city       user_id  \
# 0              34     NJ    New Jersey  Dunellen  1.125038e+20
# 1              34     NJ    New Jersey  Dunellen  1.076216e+20
# 2              34     NJ    New Jersey  Dunellen  1.142247e+20
#
#            name_y           time  rating  \
# 0   John Campbell  1544466023862       4
# 1   Cheryl Kimble  1483899014865       5
# 2  Spencer Duncan  1468894704924       4
#
#                                                 text
# 0                              Good food good prices
# 1    The food is good and they are quick to prepare.
# 2  bizarre place but the food was pretty good act...

# %% [markdown]
# ### **Transfomación de tiempo**

# %%
df_china_garden_reviews['time'] = pd.to_datetime(df_china_garden_reviews['time'], unit='ms')
df_china_garden_reviews['date'] = df_china_garden_reviews['time'].dt.date
del df_china_garden_reviews['time']

# %%
df_china_garden_reviews['date'].head()
# Out:
# 0    2018-12-10
# 1    2017-01-08
# 2    2016-07-19
# 3    2017-06-12
# 4    2015-09-15
# Name: date, dtype: object

# %%
df_china_garden_reviews['date'] = pd.to_datetime(df_china_garden_reviews['date'])
df_china_garden_reviews['year'] = df_china_garden_reviews['date'].dt.year

# %%
df_china_garden_reviews['year'].head()
# Out:
# 0    2018
# 1    2017
# 2    2016
# 3    2017
# 4    2015
# Name: year, dtype: int32

# %%
print(df_china_garden_reviews['date'].dt.date.min())
print(df_china_garden_reviews['date'].dt.date.max())
# Out:
# 2010-08-10
# 2021-06-20

# %%
plt.boxplot(df_china_garden_reviews['year'])
plt.title('Boxplot de los Años de los Reviews')
plt.ylabel('Años')
plt.xlabel('Reviews')
plt.show()

# %%
Q1 = df_china_garden_reviews['date'].dt.year.quantile(0.25)
Q3 = df_china_garden_reviews['date'].dt.year.quantile(0.75)
IQR = Q3 - Q1

# Determinar outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filtrar los registros que son outliers en los años
outliers = df_china_garden_reviews[(df_china_garden_reviews['year'] < lower_bound) | (df_china_garden_reviews['year'] > upper_bound)]


# Contar los registros por cada año outlier
outliers_count = outliers['year'].value_counts().reset_index()
outliers_count.columns = ['year', 'count']

# Mostrar el resultado
print(outliers_count)
# Out:
#    year  count
# 0  2021    137
# 1  2016     83
# 2  2015     18
# 3  2014      5
# 4  2012      5
# 5  2013      3
# 6  2010      2
# 7  2011      2

# %%
reviews_per_year_state = df_china_garden_reviews.groupby(['year', 'nombre_estado']).size().unstack().fillna(0)

# Crear el histograma apilado
reviews_per_year_state.plot(kind='bar', stacked=True, figsize=(12, 6))

# Ajustar el título y las etiquetas
plt.title('Distribución de los Reviews por Año y Estado')
plt.xlabel('Año')
plt.ylabel('Cantidad de Reviews')
plt.legend(title='Estado')

# Mostrar el gráfico
plt.show()

# %%
reviews_per_year_state = df_china_garden_reviews.groupby(['year', 'nombre_estado']).size().unstack().fillna(0)

# Crear el gráfico de barras
reviews_per_year_state.plot(kind='bar', figsize=(12, 6))

# Ajustar el título y las etiquetas
plt.title('Cantidad de Reviews por Año y Estado')
plt.xlabel('Año')
plt.ylabel('Cantidad de Reviews')
plt.legend(title='Estado')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### **Nube de palabras del Reseñas de China Garden**

# %%
import nltk
from nltk.corpus import stopwords
import wordcloud
from wordcloud import WordCloud, STOPWORDS

# Creamos la lista de palabras a excluir
stopwords = set(STOPWORDS)
stopwords.update(["br", "href", "None", "Chinese", "food"])

# Convertimos todos los valores en la columna 'text' a cadenas de texto
# y los unimos en una sola cadena
text = " ".join(str(text) for text in df_china_garden_reviews['text'] if str(text) != 'None')

# Creamos la nube de palabras
wordcloud = WordCloud(stopwords=stopwords, background_color='white', width=800, height=400).generate(text)

# Mostramos la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Nube de Palabras de las Reseñas')
plt.show()

# %% [markdown]
# ### **Nube de palabras del total de Restaurantes chinos**

# %%
df_cr.head(3)
# Out:
#                                      name  \
# 2880  China House Chinese & American Food
# 8172                                 WUJI
# 8820                        Panda Express
#
#                                                 address  \
# 2880  China House Chinese & American Food, 827 Broad...
# 8172         WUJI, 68 E Putnam Ave, Greenwich, CT 06830
# 8820  Panda Express, 13059 Lee Jackson Memorial Hwy,...
#
#                                     gmap_id   latitude  longitude  \
# 2880  0x89c6c8e87f60800d:0xbacca2e5a90bdfcb  39.935655 -75.119530
# 8172  0x89c29846a70925f3:0xd15fd18f2efe0a63  41.032745 -73.624310
# 8820  0x89b645175b2f5bf1:0x4000b96ee41f94d9  38.880261 -77.398403
#
#                 category  avg_rating  num_of_reviews estado nombre_estado  \
# 2880  Chinese restaurant         5.0               4     NJ    New Jersey
# 8172  Chinese restaurant         3.8              18     CT   Connecticut
# 8820  Chinese restaurant         3.8              48     VA      Virginia
#
#            city
# 2880     Camden
# 8172  Greenwich
# 8820    Fairfax

# %%
df_unido_cr = pd.merge(df_cr, df_review_estados, on='gmap_id', how='inner')  # inner, left, right, outer

# %%
# Creamos la lista de palabras a excluir
stopwords = set(STOPWORDS)
stopwords.update(["br", "href", "None", "Chinese", "food"])

# Convertimos todos los valores en la columna 'text' a cadenas de texto
# y los unimos en una sola cadena
text = " ".join(str(text) for text in df_unido_cr['text'] if str(text) != 'None')

# Creamos la nube de palabras
wordcloud = WordCloud(stopwords=stopwords, background_color='white', width=800, height=400).generate(text)

# Mostramos la nube de palabras
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Nube de Palabras de las Reseñas')
plt.show()

# %% [markdown]
# ### **Top 20 palabras más usadas China Garden**

# %%
# Descargamos stopwords en inglés (ya que los comentarios parecen estar en inglés)
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Agregamos palabras adicionales a excluir
stop_words.update(["br", "href", "none", "chinese", "food", "restaurant"])

# Asumimos que 'df_unido' es tu DataFrame. Si no es así, cárgalo aquí:
# df_unido = pd.read_csv('tu_archivo.csv')

# Función para limpiar y tokenizar el texto
def clean_and_tokenize(text):
    # Convertimos a minúsculas y eliminar caracteres no alfanuméricos
    text = re.sub(r'[^\w\s]', '', str(text).lower())
    # Tokenizamos (dividir en palabras individuales)
    tokens = text.split()
    # Eliminamos stopwords y palabras cortas (menos de 3 caracteres)
    return [word for word in tokens if word not in stop_words and len(word) > 2]

# Aplicamos la función a la columna 'text' y aplanar la lista
all_words = [word for sublist in df_unido['text'].apply(clean_and_tokenize) for word in sublist]

# Contamos las palabras
word_counts = Counter(all_words)

# Obtenemos las 20 palabras más frecuentes
top_20_words = word_counts.most_common(20)

# Imprimimos los resultados
print("Las 20 palabras más usadas:")
for word, count in top_20_words:
    print(f"{word}: {count}")

# Opcional: crear un DataFrame con los resultados
top_20_df_cg = pd.DataFrame(top_20_words, columns=['Palabra', 'Frecuencia'])
print(top_20_df_cg)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\54370\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 3
#       1 # Descargamos stopwords en inglés (ya que los comentarios parecen estar en inglés)
#       2 nltk.download('stopwords')
# ----> 3 stop_words = set(stopwords.words('english'))
#       5 # Agregamos palabras adicionales a excluir
#       6 stop_words.update(["br", "href", "none", "chinese", "food", "restaurant"])
#
# AttributeError: 'set' object has no attribute 'words'

# %% [markdown]
# **TOP 20 palabras más usadas en reviews de "Restaurantes Chinos"**

# %%
# Descargamos stopwords en inglés (ya que los comentarios parecen estar en inglés)
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Agregamos palabras adicionales a excluir
stop_words.update(["br", "href", "none", "chinese", "food", "restaurant"])

# Asumimos que 'df_unido' es tu DataFrame. Si no es así, cárgalo aquí:
# df_unido = pd.read_csv('tu_archivo.csv')

# Función para limpiar y tokenizar el texto
def clean_and_tokenize(text):
    # Convertimos a minúsculas y eliminar caracteres no alfanuméricos
    text = re.sub(r'[^\w\s]', '', str(text).lower())
    # Tokenizamos (dividir en palabras individuales)
    tokens = text.split()
    # Eliminamos stopwords y palabras cortas (menos de 3 caracteres)
    return [word for word in tokens if word not in stop_words and len(word) > 2]

# Aplicamos la función a la columna 'text' y aplanar la lista
all_words = [word for sublist in df_unido_cr['text'].apply(clean_and_tokenize) for word in sublist]

# Contamos las palabras
word_counts = Counter(all_words)

# Obtenemos las 20 palabras más frecuentes
top_20_words = word_counts.most_common(20)

# Imprimimos los resultados
print("Las 20 palabras más usadas:")
for word, count in top_20_words:
    print(f"{word}: {count}")

# Opcional: creamos un DataFrame con los resultados
top_20_df_cr = pd.DataFrame(top_20_words, columns=['Palabra', 'Frecuencia'])
print(top_20_df_cr)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\54370\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Las 20 palabras más usadas:
# good: 50234
# great: 32508
# place: 24352
# service: 21376
# best: 15958
# chicken: 14970
# always: 14196
# order: 12012
# love: 10647
# like: 10374
# rice: 10089
# time: 9877
# delicious: 9333
# friendly: 9148
# nice: 9053
# fresh: 8090
# get: 8052
# fried: 7672
# staff: 7503
# fast: 7203
#       Palabra  Frecuencia
# 0        good       50234
# 1       great       32508
# 2       place       24352
# 3     service       21376
# 4        best       15958
# 5     chicken       14970
# 6      always       14196
# 7       order       12012
# 8        love       10647
# 9        like       10374
# 10       rice       10089
# 11       time        9877
# 12  delicious        9333
# 13   friendly        9148
# 14       nice        9053
# 15      fresh        8090
# 16        get        8052
# 17      fried        7672
# 18      staff        7503
# 19       fast        7203

# %%
# Renombramos las columnas para distinguir entre los dos conjuntos de datos
top_20_df_cr = top_20_df_cr.rename(columns={'Frecuencia': 'Frecuencia_CR'})
top_20_df_cg = top_20_df_cg.rename(columns={'Frecuencia': 'Frecuencia_CG'})

# Combinamos los DataFrames usando un outer join en la columna 'Palabra'
df_comparativo = pd.merge(top_20_df_cr, top_20_df_cg, on='Palabra', how='outer')

# Rellenamos los valores NaN con 0
df_comparativo = df_comparativo.fillna(0)

# Ordenamos el DataFrame por la suma de las frecuencias en orden descendente
df_comparativo['Total'] = df_comparativo['Frecuencia_CR'] + df_comparativo['Frecuencia_CG']
df_comparativo = df_comparativo.sort_values('Total', ascending=False)

# Eliminamos la columna 'Total' si no la necesitas en el resultado final
df_comparativo = df_comparativo.drop('Total', axis=1)

# Reseteamos el índice
df_comparativo = df_comparativo.reset_index(drop=True)

# Mostramos el DataFrame comparativo
print(df_comparativo)

# Opcional: Guardar el DataFrame comparativo en un archivo CSV
# df_comparativo.to_csv('comparativo_palabras_frecuentes.csv', index=False)

# Opcional: Crear un gráfico de barras comparativo
plt.figure(figsize=(12, 8))
bar_width = 0.35
index = range(len(df_comparativo))

plt.bar(index, df_comparativo['Frecuencia_CR'], bar_width, label='Todos los restaurantes chinos')
plt.bar([i + bar_width for i in index], df_comparativo['Frecuencia_CG'], bar_width, label='China Garden')

plt.xlabel('Palabras')
plt.ylabel('Frecuencia')
plt.title('Comparación de las palabras más frecuentes')
plt.xticks([i + bar_width/2 for i in index], df_comparativo['Palabra'], rotation=45, ha='right')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
#       Palabra  Frecuencia_CR  Frecuencia_CG
# 0        good        50234.0          426.0
# 1       great        32508.0          227.0
# 2       place        24352.0          169.0
# 3     service        21376.0          155.0
# 4        best        15958.0          112.0
# 5     chicken        14970.0          126.0
# 6      always        14196.0          118.0
# 7       order        12012.0          104.0
# 8        love        10647.0           86.0
# 9        like        10374.0           62.0
# 10       rice        10089.0          104.0
# 11       time         9877.0           79.0
# 12  delicious         9333.0           72.0
# 13   friendly         9148.0           60.0
# 14       nice         9053.0           60.0
# 15      fresh         8090.0           58.0
# 16        get         8052.0            0.0
# 17      fried         7672.0           72.0
# 18      staff         7503.0            0.0
# 19       fast         7203.0           71.0
# 20    ordered            0.0           66.0
# 21     prices            0.0           63.0

# %% [markdown]
# # Conclusiones y Sugerencias
#
# ## 1. Distribución geográfica de restaurantes China Garden:
# - Brooklyn tiene la mayor concentración de restaurantes China Garden (3), seguido de varias ciudades con 1 restaurante cada una.
# - La calificación promedio de los restaurantes varía entre 3.3 y 4.4, con Brooklyn teniendo una calificación promedio de 3.63.
#
# ## 2. Competencia en el mercado:
# - China Wok lidera en número de locales (89), seguido por China King y Panda Express (54 cada uno).
# - China Garden se ubica en quinto lugar con 44 locales.
# - En términos de calificación promedio, China Garden se posiciona bien con 3.95, ocupando el sexto lugar entre los competidores principales.
#
# ## 3. Volumen de reseñas:
# - China Wok lidera también en número de reseñas (7708), seguido por Panda Express (6123) y China King (4571).
# - China Garden se ubica en cuarto lugar con 3595 reseñas, lo que sugiere una buena visibilidad y engagement con los clientes.
#
# ## 4. Distribución de hoteles:
# - Orlando, FL tiene la mayor concentración de hoteles (5523), seguido por Kissimmee, FL (2848) y Davenport, FL (1744).
# - Florida domina claramente en términos de infraestructura hotelera, lo que podría indicar un alto potencial turístico.
#
# ## 5. Análisis de sentimientos en reseñas:
# - Las palabras más frecuentes en las reseñas incluyen "good", "food", "great", "place", "service", y "order", lo que sugiere una experiencia generalmente positiva de los clientes.
# - La presencia de palabras como "delicious", "best", y "always" también indica satisfacción del cliente.
#
# ## Conclusiones y recomendaciones:
# 1. **Expansión geográfica:** Considerar la expansión en ciudades turísticas de Florida, aprovechando la alta concentración de hoteles y el potencial flujo de turistas.
# 2. **Mejora de la experiencia del cliente:** Enfocarse en mantener y mejorar la calidad del servicio y la comida, ya que son aspectos frecuentemente mencionados en las reseñas.
# 3. **Competencia:** Analizar las estrategias de China Wok y Panda Express para entender su éxito en términos de expansión y engagement con clientes.
# 4. **Calidad vs. Cantidad:** Aunque China Garden no lidera en número de locales, mantiene una buena calificación promedio. Considerar una estrategia de crecimiento que mantenga estos estándares de calidad.
# 5. **Marketing y presencia online:** Fomentar más reseñas de clientes para aumentar la visibilidad online, dado que las reseñas parecen ser generalmente positivas.
#
# ## Sugerencias para explorar más datos:
# 1. **Análisis temporal:** Examinar cómo han evolucionado las calificaciones y el número de reseñas a lo largo del tiempo para identificar tendencias.
# 2. **Análisis de precios:** Comparar los rangos de precios entre China Garden y sus competidores para identificar oportunidades de posicionamiento.
# 3. **Análisis demográfico:** Estudiar las características demográficas de las áreas donde China Garden tiene éxito para identificar mercados similares para expansión.
# 4. **Análisis de menú:** Identificar los platos más populares o mejor calificados para optimizar el menú.
# 5. **Análisis de sentimientos más detallado:** Realizar un análisis de sentimientos más profundo de las reseñas para identificar áreas específicas de mejora y fortalezas de la marca.
# 6. **Estudio de estacionalidad:** Analizar si hay patrones estacionales en las calificaciones o volumen de reseñas, especialmente en áreas turísticas.
#
# Estos análisis adicionales proporcionarían una base más sólida para la toma de decisiones estratégicas en la expansión y mejora de China Garden en la costa este de Estados Unidos.
